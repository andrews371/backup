# %%
# validação de método - versão baseada nos dados main leagues football data

import csv 
import statistics as st
import math
import numpy as np



def ano_dados(camp,saldo_parcial,saldo_pm,rs,mrs,acumulador,stake):
    # base de dados
    time_casa = ''
    time_fora = ''
    num_jogos = 0
    num_gols = 0
    media_gols = 0

    # para média de gols dos times
    mgf_tcasa = 0
    mgs_tcasa = 0
    mgf_tfora = 0
    mgs_tfora = 0

    # para média de gols do campeonato
    # antes da rodada em questão
    tgf_ccasa_ant = 0
    tgf_cfora_ant = 0
    mgf_ccasa_ant = 0
    mgs_ccasa_ant = 0
    mgf_cfora_ant = 0
    mgs_cfora_ant = 0

    # depois da rodada em questão
    mgf_ccasa = 0
    mgs_ccasa = 0
    mgf_cfora = 0
    mgs_cfora = 0

    time_ant = [''] * 20 # recebe dados do time antes do jogo da rodada
    time = [''] * 20     # recebe dados do time depois de ser realizado o jogo da rodada em quetão

    tgf_ccasa = 0
    tgf_cfora = 0

    cont1 = 0
    cont_jogos = 0
    rodada = 1
    cont_geral = 1
    cont_ind = [0] * 20

    time1_ant = ''
    time2_ant = ''
    time1 = ''
    time2 = ''
    dentro_rodada = 0

    odd_pca = 0
    odd_pea = 0
    odd_pfa = 0

    ojc = 0
    oje = 0
    ojf = 0

    resultado = ''
    num_entradas = 0

    taxa_1x0 = 0
    taxa_n1x0 = 0
    total_ja = 0

    # últimos resultados
    urc = [''] * 20
    urf = [''] * 20
    
    caux = 0
    valor_inv = 0
    
    with open(camp, 'r', encoding = 'utf-8', newline = '') as al:
        arq1 = csv.DictReader(al)
        
        for linha in arq1:
            try: 
                # odd match odds Pinnacle
                odd_pca = float(linha['PSH'])
                odd_pea = float(linha['PSD'])
                odd_pfa = float(linha['PSA']) 

                # resultado do jogo
                resultado = linha['FTR']
                resultadoht = linha['HTR']

                # média de gols do campeonato antes da rodada em questão
                tgf_ccasa_ant = tgf_ccasa
                tgf_cfora_ant = tgf_cfora
                mgf_ccasa_ant = mgf_ccasa
                mgs_ccasa_ant = mgs_ccasa
                mgf_cfora_ant = mgf_cfora
                mgs_cfora_ant = mgs_cfora

                # média de gols do campeonato depois da rodada em questão
                tgf_ccasa += float(linha['FTHG'])
                tgf_cfora += float(linha['FTAG'])
                mgf_ccasa = tgf_ccasa/cont_geral
                mgs_ccasa = tgf_cfora/cont_geral
                mgf_cfora = mgs_ccasa
                mgs_cfora = mgf_ccasa

                # carregando os times e o número de jogos de cada
                if cont1 < 10:
                    cont_ind[cont1] += 1
                    cont_ind[cont1+10] += 1
                    urc[cont1] = linha['HomeTeam']
                    urc[cont1+10] = linha['AwayTeam']
                    urf[cont1] = linha['HomeTeam']
                    urf[cont1+10] = linha['AwayTeam']

                    time[cont1] = {'time':linha['HomeTeam'],'num_jogosc':cont_ind[cont1],'num_jogosf':0,'tgf_tcasa':int(linha['FTHG']),'tgs_tcasa':int(linha['FTAG']),'tgf_tfora':0,'tgs_tfora':0,'mgf_tcasa':float(linha['FTHG'])/cont_ind[cont1],'mgs_tcasa':float(linha['FTAG'])/cont_ind[cont1],'mgf_tfora':0,'mgs_tfora':0}
                    time[cont1+10] = {'time':linha['AwayTeam'],'num_jogosc':0,'num_jogosf':cont_ind[cont1+10],'tgf_tcasa':0,'tgs_tcasa':0,'tgf_tfora':int(linha['FTAG']),'tgs_tfora':int(linha['FTHG']),'mgf_tcasa':0,'mgs_tcasa':0,'mgf_tfora':float(linha['FTAG'])/cont_ind[cont1+10],'mgs_tfora':float(linha['FTHG'])/cont_ind[cont1+10]}
                    cont1 += 1                  

                # contando jogos
                if cont_jogos <= 10:
                    cont_jogos += 1

                # atualizando os dados dos times por jogo
                if cont_geral >= 10:     
                    for i in range(20):
                        if linha['HomeTeam'] == time[i]['time']: 
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosc'] += 1
                            time[i]['tgf_tcasa'] += int(linha['FTHG'])
                            time[i]['tgs_tcasa'] += int(linha['FTAG'])

                            time[i]['mgf_tcasa'] = time[i]['tgf_tcasa']/time[i]['num_jogosc']
                            time[i]['mgs_tcasa'] = time[i]['tgs_tcasa']/time[i]['num_jogosc']

                        if linha['AwayTeam'] == time[i]['time']:
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosf'] += 1
                            time[i]['tgf_tfora'] += int(linha['FTAG'])
                            time[i]['tgs_tfora'] += int(linha['FTHG'])

                            time[i]['mgf_tfora'] = time[i]['tgf_tfora']/time[i]['num_jogosf']
                            time[i]['mgs_tfora'] = time[i]['tgs_tfora']/time[i]['num_jogosf']


                #contando rodadas - a primeira vez que entra aqui é a rodada 2
                if cont_jogos > 10 or dentro_rodada < 10:
                    # atualizando o número de rodadas
                    if cont_jogos > 10:
                        rodada += 1
                        cont_jogos = 1
                        dentro_rodada = 0



                    dentro_rodada += 1

                    #carregando times com dados da rodada para chamar o método
                    if rodada > 1:
                        for i in range(20):                 
                            if linha['HomeTeam'] == time[i]['time']:
                                time1_ant = time_ant[i] # time1 antes da rodada em questão
                                time1 = time[i]         # time1 depois da rodada em questão
                            if linha['AwayTeam'] == time[i]['time']:
                                time2_ant = time_ant[i] # time2 antes da rodada em questão
                                time2 = time[i]         # time2 depois da rodada em questão


                    #print('número de jogos: {}'.format(cont_geral))
                    # chamando o método para cálculo de probabilidades
                    
                    if rodada > 0:
                        if odd_pca >= 1.9 and odd_pca <= 3 and int(linha['HST']) <= (int(linha['AST']) + 2) :
                            #acumulador += 1
                            
                            # para juros compostos
                            if (0.01083 * saldo_parcial) <= 2000:
                                stake2 = 0.01083 * saldo_parcial
                            else:
                                stake2 = 2000
                                #print(f'partidas jogadas até stake de 2000 {acumulador}')                                
                            
                            # para usar stake fixa basta descomentar a linha abaixo
                            #stake2 = stake
                            
                            # Análise de banca quebrada
                            if saldo_parcial < stake2:
                                print('VOCÊ QUEBROU A BANCA')
                            
                            if resultado == 'H' and int(linha['FTHG']) >= 4 :
                                taxa_1x0 += 1
                                saldo_parcial -= stake2 * 24
                                rs += 1
                                print(f'Red {saldo_parcial:.2f}')
                                
                            else:
                                taxa_n1x0 += 1
                                saldo_parcial += stake2 
                                rs = 0
                                print(f'Green {saldo_parcial:.2f}')
                           
                            # verificação de reds seguidos
                            if rs > mrs:
                                mrs = rs
                            
                            # verificação de saldo mínimo
                            if saldo_parcial < saldo_pm:
                                saldo_pm = saldo_parcial
                            
                            # Para cálculo de ROI    
                            valor_inv += stake2  
                            
                            # Total de entradas feitas
                            total_ja += 1
                        
                            
                        elif odd_pfa >= 1.9 and odd_pfa <= 3 and int(linha['AST']) <= (int(linha['HST']) + 2) :
                            #acumulador += 1
                            
                            # para juros compostos    
                            if (0.01083 * saldo_parcial) <= 2000:
                                stake2 = 0.01083 * saldo_parcial
                            else:
                                stake2 = 2000
                                #print(f'partidas jogadas até stake de 2000 {acumulador}')                                
                            
                            # para usar stake fixa basta descomentar a linha abaixo
                            #stake2 = stake
                            
                            # Análise de banca quebrada
                            if saldo_parcial < stake2:
                                print('VOCÊ QUEBROU A BANCA')
                            
                            if resultado == 'A' and int(linha['FTAG']) >= 4 :
                                taxa_1x0 += 1
                                saldo_parcial -= stake2 * 24
                                rs += 1
                                print(f'Red {saldo_parcial:.2f}')
                                
                            else:
                                taxa_n1x0 += 1
                                saldo_parcial += stake2 
                                rs = 0 
                                print(f'Green {saldo_parcial:.2f}')
                            
                            # verificação de reds seguidos
                            if rs > mrs:
                                mrs = rs
                            
                            # verificação de saldo mínimo
                            if saldo_parcial < saldo_pm:
                                saldo_pm = saldo_parcial
                            
                            # Para cálculo de ROI    
                            valor_inv += stake2  
                            
                            # Total de entradas feitas
                            total_ja += 1 
                        
                cont_geral += 1
            except:
                continue
                
    return saldo_parcial,saldo_pm,cont_geral-1,taxa_n1x0,taxa_1x0,total_ja,rs,mrs,valor_inv,acumulador
        
    
# programa principal
# ano a ser avaliado
ent2 = input('Campeonato: ')

# para fazer cálculo de lucro ou perda por mês depois
meses = 0 

tam_ent2 = len(ent2.split(','))
ent2 = ent2.split(',')

for i in range(tam_ent2): 
    if i == 0:
        if ent2[i].lower() == 's': # aqui poderia ser upper() no lugar de lower() mas a letra depois de "==" teria que ser maiúscula
            entrada2 = 's1,s2,s3,s4,s5,s6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'p':
            entrada2 = 'p1,p2,p3,p4,p5,p6,p7,p8,p9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'e':
            entrada2 = 'e1,e2,e3,e4,e5,e6,e7'.upper().split(',')
            meses = 84
        elif ent2[i].lower() == 'ec':
            entrada2 = 'ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8'.upper().split(',')
            meses = 96
        elif ent2[i].lower() == 't':
            entrada2 = 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'b':
            entrada2 = 'b1,b2,b3,b4,b5,b6,b7,b8,b9,b10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'f':
            entrada2 = 'f1,f2,f3,f4,f5,f6,f7,f8,f9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'g':
            entrada2 = 'g1,g2,g3,g4,g5,g6,g7,g8,g9,g10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'i':
            entrada2 = 'i1,i2,i3,i4,i5,i6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'd':
            entrada2 = 'd1,d2,d3,d4,d5,d6,d7,d8,d9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'n':
            entrada2 = 'n1,n2,n3,n4,n5,n6,n7,n8,n9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'sc':
            entrada2 = 'sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')
            meses = 108
        elif ent2[i] == '1':
            entrada2 = 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1'.upper().split(',')
            meses = 12
        elif ent2[i] == '2':
            entrada2 = 's2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2'.upper().split(',')
            meses = 12
        elif ent2[i] == '3':
            entrada2 = 's3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3'.upper().split(',')
            meses = 12
        elif ent2[i] == '4':
            entrada2 = 's4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4'.upper().split(',')
            meses = 12
        elif ent2[i] == '5':
            entrada2 = 's5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5'.upper().split(',')
            meses = 12
        elif ent2[i] == '6':
            entrada2 = 's6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')
            meses = 12
        elif ent2[i].lower() == '6 anos':
            entrada2 = 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1,s2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2,s3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3,s4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4,s5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5,s6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')    
            meses = 72
        elif ent2[i].lower() == 'todos':
            entrada2 = 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10,b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,e1,e2,e3,e4,e5,e6,e7,ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8,ec9,f1,f2,f3,f4,f5,f6,f7,f8,f9,g,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,i1,i2,i3,i4,i5,i6,n1,n2,n3,n4,n5,n6,n7,n8,n9,p1,p2,p3,p4,p5,p6,p7,p8,p9,s1,s2,s3,s4,s5,s6,sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')  
            meses = 'NULL'
        else:
            try:
                int(ent2[i])
                entrada2 = ent2.upper().split(',') # campeonato -> entrada2
                meses = tam_ent2 * 12
            except:
                continue
    else:
        if ent2[i].lower() == 's': # aqui poderia ser upper() no lugar de lower() mas a letra depois de "==" teria que ser maiúscula
            entrada2 += 's1,s2,s3,s4,s5,s6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'p':
            entrada2 += 'p1,p2,p3,p4,p5,p6,p7,p8,p9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'e':
            entrada2 += 'e1,e2,e3,e4,e5,e6,e7'.upper().split(',')
            meses = 84
        elif ent2[i].lower() == 'ec':
            entrada2 += 'ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8'.upper().split(',')
            meses = 96
        elif ent2[i].lower() == 't':
            entrada2 += 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'b':
            entrada2 += 'b1,b2,b3,b4,b5,b6,b7,b8,b9,b10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'f':
            entrada2 += 'f1,f2,f3,f4,f5,f6,f7,f8,f9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'g':
            entrada2 += 'g1,g2,g3,g4,g5,g6,g7,g8,g9,g10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'i':
            entrada2 += 'i1,i2,i3,i4,i5,i6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'd':
            entrada2 += 'd1,d2,d3,d4,d5,d6,d7,d8,d9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'n':
            entrada2 += 'n1,n2,n3,n4,n5,n6,n7,n8,n9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'sc':
            entrada2 += 'sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')
            meses = 108
        elif ent2[i] == '1':
            entrada2 += 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1'.upper().split(',')
            meses += 12
        elif ent2[i] == '2':
            entrada2 += 's2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2'.upper().split(',')
            meses += 12
        elif ent2[i] == '3':
            entrada2 += 's3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3'.upper().split(',')
            meses += 12
        elif ent2[i] == '4':
            entrada2 += 's4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4'.upper().split(',')
            meses += 12
        elif ent2[i] == '5':
            entrada2 += 's5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5'.upper().split(',')
            meses += 12
        elif ent2[i] == '6':
            entrada2 += 's6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')
            meses += 12
        else:
            try:
                int(ent2[i])
                entrada2 = ent2.upper().split(',') # campeonato -> entrada2
                meses = tam_ent2 * 12
            except:
                continue
        
tam_entrada2 = len(entrada2)

print('\n')

for i in range(tam_entrada2):
    entrada2[i] +='.csv'

acumulador = 0
taxa_n1x0 = 0
taxa_1x0 = 0
total_ja = 0
num_jogos = 0
rs = 0
mrs = 0
fmrs = 0
caux = 0
saldo_pm = 100000 # valor fixo que tem que ser maior que a banca

fvalor_inv = 0
valor_inv = 0
fcaux = 0
frs = 0
valor_inicial = 9
stake = valor_inicial * 0.2
stake = 3
perc_banca = 0
roi = 0
saldo_final = valor_inicial
saldo_parcial = saldo_final
fnum_jogos = 0
ftaxa_n1x0 = 0
ftaxa_1x0 = 0
ftotal_ja = 0

ftaxa_al = []
ftaxa_ab = []

for i in range(tam_entrada2):
    try:
        saldo_parcial,saldo_pm,num_jogos,taxa_n1x0,taxa_1x0,total_ja,rs,mrs,valor_inv,acumulador = ano_dados(entrada2[i],saldo_parcial,saldo_pm,rs,mrs,acumulador,stake)
        fcaux += caux
        saldo_final += saldo_parcial
        fnum_jogos += num_jogos
        ftaxa_n1x0 += taxa_n1x0
        ftaxa_1x0 += taxa_1x0
        ftotal_ja += total_ja
        ftaxa_al.append((ftaxa_n1x0*100) / ftotal_ja)
        ftaxa_ab.append((ftaxa_1x0*100) / ftotal_ja)
        fvalor_inv += valor_inv
        
        #print('Banca parcial {s:.2f}\n'.format(s = saldo_final))
    except:
        continue
        

if ftotal_ja == 0:
    print('Nenhum jogo encontrado')
    
else:
    d_odd_lay = (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))             
    
    if d_odd_lay == 0:
        print(f'Total de jogos analisados: {ftotal_ja}')
        print('Nenhum deles foi 1x0\n')
    else:
        saldo_final = saldo_parcial
        odd_lay = 100 / (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))
        odd_back = 100 / ((ftaxa_1x0 * 100) / (ftotal_ja)) 
        so_odd_lay = 100 / (100 - st.median(ftaxa_al))
        so_odd_back = 100 / st.median(ftaxa_ab)

        # Cálculo da média de lucros e ROI mensal
        if ent2[0].lower() != 'todos':
            perc_banca = (((saldo_final - valor_inicial) / meses) * 100) / valor_inicial
            roi = (((saldo_final - valor_inicial) / meses) * 100) / ((fvalor_inv) / meses)
            
        print(f'\nTotal de jogos: {fnum_jogos}')
        print(f'Total de jogos analisados: {ftotal_ja}\n')
        
        print(f'Máximo de reds seguidos {mrs}')
        print(f'Saldo mínimo na temporada {saldo_pm:.2f}')
        print('taxa de 1x0: {} -> {t:.2f}%'.format(ftaxa_1x0,t = (ftaxa_1x0*100) / ftotal_ja))
        print(f'taxa de 1x0 (tirando outliers): {st.median(ftaxa_ab):.2f}%')
        print(f'Odd back ideal ACIMA de: {odd_back:.2f}')
        print(f'Odd back ideal (tirando outliers) ACIMA de: {so_odd_back:.2f}\n')

        print('taxa de nao 1x0: {} -> {tn:.2f}%'.format(ftaxa_n1x0,tn = (ftaxa_n1x0*100) / ftotal_ja))
        print(f'taxa de não 1x0 (tirando outliers): {st.median(ftaxa_al):.2f}%')
        print(f'Odd lay ideal ABAIXO de: {odd_lay:.2f}')
# Green 408.62
# Green 413.05
# Green 417.52
# Green 422.04
# Red 312.34
# Green 315.73
# Green 319.15
# Green 322.60
# Green 326.10
# Green 329.63
# Green 333.20
# Green 336.81
# Green 340.45
# Green 344.14
# Green 347.87
# Green 351.64
# Green 355.44
# Green 359.29
# Green 363.18
# Green 367.12
# Green 371.09
# Green 375.11
# Green 379.17
# Green 383.28
# Green 387.43
# Red 286.73
# Green 289.84
# Green 292.97
# Green 296.15
# Green 299.35
# Green 302.60
# Green 305.87
# Green 309.19
# Green 312.54
# Green 315.92
# Green 319.34
# Green 322.80
# Green 326.30
# Green 329.83
# Red 244.10
# Green 246.74
# Green 249.42
# Green 252.12
# Green 254.85
# Green 257.61
# Green 260.40
# Green 263.22
# Green 266.07
# Green 268.95
# Green 271.86
# Green 274.81
# Green 277.78
# Green 280.79
# Green 283.83
# Green 286.91
# Green 290.01
# Green 293.15
# Green 296.33
# Green 299.54
# Green 302.78
# Green 306.06
#
# Total de jogos: 3513
# Total de jogos analisados: 1488
#
# Máximo de reds seguidos 2
# Saldo mínimo na temporada 7.50
# taxa de 1x0: 40 -> 2.69%
# taxa de 1x0 (tirando outliers): 2.46%
# Odd back ideal ACIMA de: 37.20
# Odd back ideal (tirando outliers) ACIMA de: 40.62
#
# taxa de nao 1x0: 1448 -> 97.31%
# taxa de não 1x0 (tirando outliers): 97.54%
# Odd lay ideal ABAIXO de: 37.20
# Odd lay ideal (tirando outliers) ABAIXO de: 40.62
#
# Banca inicial 9.00
# Stake usada 3
# Saldo final 315.73
# Lucro médio mensal 25.56
# Percentual de lucro médio mensal sobre a banca 284.01%
# Roi médio mensal 10.27%

# %%
# validação de método - versão baseada nos dados main leagues football data

import csv 
import statistics as st
import math
import numpy as np



def ano_dados(camp,saldo_parcial,saldo_pm,rs,mrs,acumulador,stake):
    # base de dados
    time_casa = ''
    time_fora = ''
    num_jogos = 0
    num_gols = 0
    media_gols = 0

    # para média de gols dos times
    mgf_tcasa = 0
    mgs_tcasa = 0
    mgf_tfora = 0
    mgs_tfora = 0

    # para média de gols do campeonato
    # antes da rodada em questão
    tgf_ccasa_ant = 0
    tgf_cfora_ant = 0
    mgf_ccasa_ant = 0
    mgs_ccasa_ant = 0
    mgf_cfora_ant = 0
    mgs_cfora_ant = 0

    # depois da rodada em questão
    mgf_ccasa = 0
    mgs_ccasa = 0
    mgf_cfora = 0
    mgs_cfora = 0

    time_ant = [''] * 20 # recebe dados do time antes do jogo da rodada
    time = [''] * 20     # recebe dados do time depois de ser realizado o jogo da rodada em quetão

    tgf_ccasa = 0
    tgf_cfora = 0

    cont1 = 0
    cont_jogos = 0
    rodada = 1
    cont_geral = 1
    cont_ind = [0] * 20

    time1_ant = ''
    time2_ant = ''
    time1 = ''
    time2 = ''
    dentro_rodada = 0

    odd_pca = 0
    odd_pea = 0
    odd_pfa = 0

    ojc = 0
    oje = 0
    ojf = 0

    resultado = ''
    num_entradas = 0

    taxa_1x0 = 0
    taxa_n1x0 = 0
    total_ja = 0

    # últimos resultados
    urc = [''] * 20
    urf = [''] * 20
    
    caux = 0
    valor_inv = 0
    
    with open(camp, 'r', encoding = 'utf-8', newline = '') as al:
        arq1 = csv.DictReader(al)
        
        for linha in arq1:
            try: 
                # odd match odds Pinnacle
                odd_pca = float(linha['PSH'])
                odd_pea = float(linha['PSD'])
                odd_pfa = float(linha['PSA']) 

                # resultado do jogo
                resultado = linha['FTR']
                resultadoht = linha['HTR']

                # média de gols do campeonato antes da rodada em questão
                tgf_ccasa_ant = tgf_ccasa
                tgf_cfora_ant = tgf_cfora
                mgf_ccasa_ant = mgf_ccasa
                mgs_ccasa_ant = mgs_ccasa
                mgf_cfora_ant = mgf_cfora
                mgs_cfora_ant = mgs_cfora

                # média de gols do campeonato depois da rodada em questão
                tgf_ccasa += float(linha['FTHG'])
                tgf_cfora += float(linha['FTAG'])
                mgf_ccasa = tgf_ccasa/cont_geral
                mgs_ccasa = tgf_cfora/cont_geral
                mgf_cfora = mgs_ccasa
                mgs_cfora = mgf_ccasa

                # carregando os times e o número de jogos de cada
                if cont1 < 10:
                    cont_ind[cont1] += 1
                    cont_ind[cont1+10] += 1
                    urc[cont1] = linha['HomeTeam']
                    urc[cont1+10] = linha['AwayTeam']
                    urf[cont1] = linha['HomeTeam']
                    urf[cont1+10] = linha['AwayTeam']

                    time[cont1] = {'time':linha['HomeTeam'],'num_jogosc':cont_ind[cont1],'num_jogosf':0,'tgf_tcasa':int(linha['FTHG']),'tgs_tcasa':int(linha['FTAG']),'tgf_tfora':0,'tgs_tfora':0,'mgf_tcasa':float(linha['FTHG'])/cont_ind[cont1],'mgs_tcasa':float(linha['FTAG'])/cont_ind[cont1],'mgf_tfora':0,'mgs_tfora':0}
                    time[cont1+10] = {'time':linha['AwayTeam'],'num_jogosc':0,'num_jogosf':cont_ind[cont1+10],'tgf_tcasa':0,'tgs_tcasa':0,'tgf_tfora':int(linha['FTAG']),'tgs_tfora':int(linha['FTHG']),'mgf_tcasa':0,'mgs_tcasa':0,'mgf_tfora':float(linha['FTAG'])/cont_ind[cont1+10],'mgs_tfora':float(linha['FTHG'])/cont_ind[cont1+10]}
                    cont1 += 1                  

                # contando jogos
                if cont_jogos <= 10:
                    cont_jogos += 1

                # atualizando os dados dos times por jogo
                if cont_geral >= 10:     
                    for i in range(20):
                        if linha['HomeTeam'] == time[i]['time']: 
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosc'] += 1
                            time[i]['tgf_tcasa'] += int(linha['FTHG'])
                            time[i]['tgs_tcasa'] += int(linha['FTAG'])

                            time[i]['mgf_tcasa'] = time[i]['tgf_tcasa']/time[i]['num_jogosc']
                            time[i]['mgs_tcasa'] = time[i]['tgs_tcasa']/time[i]['num_jogosc']

                        if linha['AwayTeam'] == time[i]['time']:
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosf'] += 1
                            time[i]['tgf_tfora'] += int(linha['FTAG'])
                            time[i]['tgs_tfora'] += int(linha['FTHG'])

                            time[i]['mgf_tfora'] = time[i]['tgf_tfora']/time[i]['num_jogosf']
                            time[i]['mgs_tfora'] = time[i]['tgs_tfora']/time[i]['num_jogosf']


                #contando rodadas - a primeira vez que entra aqui é a rodada 2
                if cont_jogos > 10 or dentro_rodada < 10:
                    # atualizando o número de rodadas
                    if cont_jogos > 10:
                        rodada += 1
                        cont_jogos = 1
                        dentro_rodada = 0



                    dentro_rodada += 1

                    #carregando times com dados da rodada para chamar o método
                    if rodada > 1:
                        for i in range(20):                 
                            if linha['HomeTeam'] == time[i]['time']:
                                time1_ant = time_ant[i] # time1 antes da rodada em questão
                                time1 = time[i]         # time1 depois da rodada em questão
                            if linha['AwayTeam'] == time[i]['time']:
                                time2_ant = time_ant[i] # time2 antes da rodada em questão
                                time2 = time[i]         # time2 depois da rodada em questão


                    #print('número de jogos: {}'.format(cont_geral))
                    # chamando o método para cálculo de probabilidades
                    
                    if rodada > 0:
                        if odd_pca >= 1.9 and int() :
                            if int(linha['HST']) > int(linha['AST']) :
                            #acumulador += 1
                            
                                # para juros compostos
                                if (0.05 * saldo_parcial) <= 2000:
                                    stake2 = 0.05 * saldo_parcial
                                else:
                                    stake2 = 2000
                                    #print(f'partidas jogadas até stake de 2000 {acumulador}')                                

                                # para usar stake fixa basta descomentar a linha abaixo
                                stake2 = stake

                                # Análise de banca quebrada
                                if saldo_parcial < stake2:
                                    print('VOCÊ QUEBROU A BANCA')

                                if resultado == 'H' :
                                    taxa_1x0 += 1
                                    saldo_parcial += stake2 * (odd_pca - 1)
                                    rs = 0
                                    print(f'Green {saldo_parcial:.2f}')

                                else:
                                    taxa_n1x0 += 1
                                    saldo_parcial -= stake2 
                                    rs += 1
                                    print(f'Red {saldo_parcial:.2f}')

                                # verificação de reds seguidos
                                if rs > mrs:
                                    mrs = rs

                                # verificação de saldo mínimo
                                if saldo_parcial < saldo_pm:
                                    saldo_pm = saldo_parcial

                                # Para cálculo de ROI    
                                valor_inv += stake2  

                                # Total de entradas feitas
                                total_ja += 1

                            
                    elif odd_pfa >= 1.9 :
                            #acumulador += 1
                            if int(linha['HST']) > int(linha['AST']) :

                                # para juros compostos    
                                if (0.05 * saldo_parcial) <= 2000:
                                    stake2 = 0.05 * saldo_parcial
                                else:
                                    stake2 = 2000
                                    #print(f'partidas jogadas até stake de 2000 {acumulador}')                                

                                # para usar stake fixa basta descomentar a linha abaixo
                                stake2 = stake

                                # Análise de banca quebrada
                                if saldo_parcial < stake2:
                                    print('VOCÊ QUEBROU A BANCA')

                                if resultado == 'A' :
                                    taxa_1x0 += 1
                                    saldo_parcial += stake2 * (odd_pfa - 1)
                                    rs = 0
                                    print(f'Green {saldo_parcial:.2f}')

                                else:
                                    taxa_n1x0 += 1
                                    saldo_parcial -= stake2 
                                    rs += 1 
                                    print(f'Red {saldo_parcial:.2f}')

                                # verificação de reds seguidos
                                if rs > mrs:
                                    mrs = rs

                                # verificação de saldo mínimo
                                if saldo_parcial < saldo_pm:
                                    saldo_pm = saldo_parcial

                                # Para cálculo de ROI    
                                valor_inv += stake2  

                                # Total de entradas feitas
                                total_ja += 1 
                        
                cont_geral += 1
            except:
                continue
                
    return saldo_parcial,saldo_pm,cont_geral-1,taxa_n1x0,taxa_1x0,total_ja,rs,mrs,valor_inv,acumulador
        
    
# programa principal
# ano a ser avaliado
ent2 = input('Campeonato: ')

# para fazer cálculo de lucro ou perda por mês depois
meses = 0 

tam_ent2 = len(ent2.split(','))
ent2 = ent2.split(',')

for i in range(tam_ent2): 
    if i == 0:
        if ent2[i].lower() == 's': # aqui poderia ser upper() no lugar de lower() mas a letra depois de "==" teria que ser maiúscula
            entrada2 = 's1,s2,s3,s4,s5,s6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'p':
            entrada2 = 'p1,p2,p3,p4,p5,p6,p7,p8,p9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'e':
            entrada2 = 'e1,e2,e3,e4,e5,e6,e7'.upper().split(',')
            meses = 84
        elif ent2[i].lower() == 'ec':
            entrada2 = 'ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8'.upper().split(',')
            meses = 96
        elif ent2[i].lower() == 't':
            entrada2 = 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'b':
            entrada2 = 'b1,b2,b3,b4,b5,b6,b7,b8,b9,b10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'f':
            entrada2 = 'f1,f2,f3,f4,f5,f6,f7,f8,f9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'g':
            entrada2 = 'g1,g2,g3,g4,g5,g6,g7,g8,g9,g10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'i':
            entrada2 = 'i1,i2,i3,i4,i5,i6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'd':
            entrada2 = 'd1,d2,d3,d4,d5,d6,d7,d8,d9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'n':
            entrada2 = 'n1,n2,n3,n4,n5,n6,n7,n8,n9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'sc':
            entrada2 = 'sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')
            meses = 108
        elif ent2[i] == '1':
            entrada2 = 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1'.upper().split(',')
            meses = 12
        elif ent2[i] == '2':
            entrada2 = 's2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2'.upper().split(',')
            meses = 12
        elif ent2[i] == '3':
            entrada2 = 's3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3'.upper().split(',')
            meses = 12
        elif ent2[i] == '4':
            entrada2 = 's4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4'.upper().split(',')
            meses = 12
        elif ent2[i] == '5':
            entrada2 = 's5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5'.upper().split(',')
            meses = 12
        elif ent2[i] == '6':
            entrada2 = 's6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')
            meses = 12
        elif ent2[i].lower() == '6 anos':
            entrada2 = 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1,s2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2,s3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3,s4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4,s5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5,s6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')    
            meses = 72
        elif ent2[i].lower() == 'todos':
            entrada2 = 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10,b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,e1,e2,e3,e4,e5,e6,e7,ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8,ec9,f1,f2,f3,f4,f5,f6,f7,f8,f9,g,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,i1,i2,i3,i4,i5,i6,n1,n2,n3,n4,n5,n6,n7,n8,n9,p1,p2,p3,p4,p5,p6,p7,p8,p9,s1,s2,s3,s4,s5,s6,sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')  
            meses = 'NULL'
        else:
            try:
                int(ent2[i])
                entrada2 = ent2.upper().split(',') # campeonato -> entrada2
                meses = tam_ent2 * 12
            except:
                continue
    else:
        if ent2[i].lower() == 's': # aqui poderia ser upper() no lugar de lower() mas a letra depois de "==" teria que ser maiúscula
            entrada2 += 's1,s2,s3,s4,s5,s6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'p':
            entrada2 += 'p1,p2,p3,p4,p5,p6,p7,p8,p9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'e':
            entrada2 += 'e1,e2,e3,e4,e5,e6,e7'.upper().split(',')
            meses = 84
        elif ent2[i].lower() == 'ec':
            entrada2 += 'ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8'.upper().split(',')
            meses = 96
        elif ent2[i].lower() == 't':
            entrada2 += 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'b':
            entrada2 += 'b1,b2,b3,b4,b5,b6,b7,b8,b9,b10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'f':
            entrada2 += 'f1,f2,f3,f4,f5,f6,f7,f8,f9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'g':
            entrada2 += 'g1,g2,g3,g4,g5,g6,g7,g8,g9,g10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'i':
            entrada2 += 'i1,i2,i3,i4,i5,i6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'd':
            entrada2 += 'd1,d2,d3,d4,d5,d6,d7,d8,d9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'n':
            entrada2 += 'n1,n2,n3,n4,n5,n6,n7,n8,n9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'sc':
            entrada2 += 'sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')
            meses = 108
        elif ent2[i] == '1':
            entrada2 += 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1'.upper().split(',')
            meses += 12
        elif ent2[i] == '2':
            entrada2 += 's2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2'.upper().split(',')
            meses += 12
        elif ent2[i] == '3':
            entrada2 += 's3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3'.upper().split(',')
            meses += 12
        elif ent2[i] == '4':
            entrada2 += 's4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4'.upper().split(',')
            meses += 12
        elif ent2[i] == '5':
            entrada2 += 's5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5'.upper().split(',')
            meses += 12
        elif ent2[i] == '6':
            entrada2 += 's6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')
            meses += 12
        else:
            try:
                int(ent2[i])
                entrada2 = ent2.upper().split(',') # campeonato -> entrada2
                meses = tam_ent2 * 12
            except:
                continue
        
tam_entrada2 = len(entrada2)

print('\n')

for i in range(tam_entrada2):
    entrada2[i] +='.csv'

acumulador = 0
taxa_n1x0 = 0
taxa_1x0 = 0
total_ja = 0
num_jogos = 0
rs = 0
mrs = 0
fmrs = 0
caux = 0
saldo_pm = 100000 # valor fixo que tem que ser maior que a banca

fvalor_inv = 0
valor_inv = 0
fcaux = 0
frs = 0
valor_inicial = 100
stake = valor_inicial * 0.05
#stake = 3
perc_banca = 0
roi = 0
saldo_final = valor_inicial
saldo_parcial = saldo_final
fnum_jogos = 0
ftaxa_n1x0 = 0
ftaxa_1x0 = 0
ftotal_ja = 0

ftaxa_al = []
ftaxa_ab = []

for i in range(tam_entrada2):
    try:
        saldo_parcial,saldo_pm,num_jogos,taxa_n1x0,taxa_1x0,total_ja,rs,mrs,valor_inv,acumulador = ano_dados(entrada2[i],saldo_parcial,saldo_pm,rs,mrs,acumulador,stake)
        fcaux += caux
        saldo_final += saldo_parcial
        fnum_jogos += num_jogos
        ftaxa_n1x0 += taxa_n1x0
        ftaxa_1x0 += taxa_1x0
        ftotal_ja += total_ja
        ftaxa_al.append((ftaxa_n1x0*100) / ftotal_ja)
        ftaxa_ab.append((ftaxa_1x0*100) / ftotal_ja)
        fvalor_inv += valor_inv
        
        #print('Banca parcial {s:.2f}\n'.format(s = saldo_final))
    except:
        continue
        

if ftotal_ja == 0:
    print('Nenhum jogo encontrado')
    
else:
    d_odd_lay = (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))             
    
    if d_odd_lay == 0:
        print(f'Total de jogos analisados: {ftotal_ja}')
        print('Nenhum deles foi 1x0\n')
    else:
        saldo_final = saldo_parcial
        odd_lay = 100 / (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))
        odd_back = 100 / ((ftaxa_1x0 * 100) / (ftotal_ja)) 
        so_odd_lay = 100 / (100 - st.median(ftaxa_al))
        so_odd_back = 100 / st.median(ftaxa_ab)

        # Cálculo da média de lucros e ROI mensal
        if ent2[0].lower() != 'todos':
            perc_banca = (((saldo_final - valor_inicial) / meses) * 100) / valor_inicial
            roi = (((saldo_final - valor_inicial) / meses) * 100) / ((fvalor_inv) / meses)
            
        print(f'\nTotal de jogos: {fnum_jogos}')
        print(f'Total de jogos analisados: {ftotal_ja}\n')
        
        print(f'Máximo de reds seguidos {mrs}')
        print(f'Saldo mínimo na temporada {saldo_pm:.2f}')
        print('taxa de 1x0: {} -> {t:.2f}%'.format(ftaxa_1x0,t = (ftaxa_1x0*100) / ftotal_ja))
        print(f'taxa de 1x0 (tirando outliers): {st.median(ftaxa_ab):.2f}%')
        print(f'Odd back ideal ACIMA de: {odd_back:.2f}')
        print(f'Odd back ideal (tirando outliers) ACIMA de: {so_odd_back:.2f}\n')

        print('taxa de nao 1x0: {} -> {tn:.2f}%'.format(ftaxa_n1x0,tn = (ftaxa_n1x0*100) / ftotal_ja))
        print(f'taxa de não 1x0 (tirando outliers): {st.median(ftaxa_al):.2f}%')
        print(f'Odd lay ideal ABAIXO de: {odd_lay:.2f}')
        print(f'Odd lay ideal (tirando outliers) ABAIXO de: {so_odd_lay:.2f}\n')
        print(f'Banca inicial {valor_inicial:.2f}')
        print(f'Stake usada {stake}')
        print(f'Saldo final {saldo_final:.2f}')
        
        if meses != 'NULL':
            print(f'Lucro médio mensal {((saldo_final - valor_inicial) / meses):.2f}')
        
        if ent2[0].lower() != 'todos':
            print(f'Percentual de lucro médio mensal sobre a banca {perc_banca:.2f}%')
            print(f'Roi médio mensal {roi:.2f}%')
# Out:
# Campeonato: 1
#
#
# Red 95.00
# Red 90.00
# Green 95.05
# Green 106.00
# Green 125.65
# Green 134.50
# Red 129.50
# Red 124.50
# Red 119.50
# Green 124.90
# Red 119.90
# Green 124.70
# Green 181.20
# Green 197.35
# Green 202.80
# Red 197.80
# Red 192.80
# Red 187.80
# Green 193.90
# Red 188.90
# Green 194.40
# Green 201.10
# Green 205.95
# Red 200.95
# Red 195.95
# Red 190.95
# Green 197.20
# Green 201.85
# Green 212.75
# Green 217.75
# Green 225.15
# Green 230.65
# Red 225.65
# Green 230.75
# Red 225.75
# Green 232.20
# Green 257.00
# Red 252.00
# Red 247.00
# Green 253.25
# Green 260.35
# Red 255.35
# Green 264.55
# Red 259.55
# Red 254.55
# Green 259.45
# Red 254.45
# Red 249.45
# Red 244.45
# Red 239.45
# Green 245.15
# Red 240.15
# Green 250.90
# Green 262.30
# Red 257.30
# Green 265.25
# Green 270.30
# Red 265.30
# Green 270.30
# Green 275.75
# Green 281.35
# Green 286.80
# Red 281.80
