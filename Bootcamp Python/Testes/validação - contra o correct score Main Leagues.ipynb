# %%
### manipulando tabela do brasileirão série A a partir de 2012
# para verificação de estratégia de resultados corretos - versão baseada nos dados main leagues football data

import csv 
import statistics as st
import math
import numpy as np



def ano_dados(camp):
    # base de dados
    time_casa = ''
    time_fora = ''
    num_jogos = 0
    num_gols = 0
    media_gols = 0

    # para média de gols dos times
    mgf_tcasa = 0
    mgs_tcasa = 0
    mgf_tfora = 0
    mgs_tfora = 0

    # para média de gols do campeonato
    # antes da rodada em questão
    tgf_ccasa_ant = 0
    tgf_cfora_ant = 0
    mgf_ccasa_ant = 0
    mgs_ccasa_ant = 0
    mgf_cfora_ant = 0
    mgs_cfora_ant = 0

    # depois da rodada em questão
    mgf_ccasa = 0
    mgs_ccasa = 0
    mgf_cfora = 0
    mgs_cfora = 0

    time_ant = [''] * 20 # recebe dados do time antes do jogo da rodada
    time = [''] * 20     # recebe dados do time depois de ser realizado o jogo da rodada em quetão

    tgf_ccasa = 0
    tgf_cfora = 0

    cont1 = 0
    cont_jogos = 0
    rodada = 1
    cont_geral = 1
    cont_ind = [0] * 20

    time1_ant = ''
    time2_ant = ''
    time1 = ''
    time2 = ''
    dentro_rodada = 0

    odd_pca = 0
    odd_pea = 0
    odd_pfa = 0

    ojc = 0
    oje = 0
    ojf = 0

    resultado = ''
    saldo = 0
    num_entradas = 0

    taxa_1x0 = 0
    taxa_n1x0 = 0
    total_ja = 0

    # últimos resultados
    urc = [''] * 20
    urf = [''] * 20
    
    # reds seguidos
    rs = 0
    mrs = 0
    
    with open(camp, 'r', encoding = 'utf-8', newline = '') as al:
        arq1 = csv.DictReader(al)
        for linha in arq1:
            try:
                
                lnvazia = int(linha['FTHG'])
                lnvazia = int(linha['FTAG'])
                
                # odd match odds Pinnacle
                odd_pca = float(linha['PSH'])
                odd_pea = float(linha['PSD'])
                odd_pfa = float(linha['PSA']) 

                # resultado do jogo
                resultado = linha['FTR']

                # média de gols do campeonato antes da rodada em questão
                tgf_ccasa_ant = tgf_ccasa
                tgf_cfora_ant = tgf_cfora
                mgf_ccasa_ant = mgf_ccasa
                mgs_ccasa_ant = mgs_ccasa
                mgf_cfora_ant = mgf_cfora
                mgs_cfora_ant = mgs_cfora

                # média de gols do campeonato depois da rodada em questão
                tgf_ccasa += float(linha['FTHG'])
                tgf_cfora += float(linha['FTAG'])
                mgf_ccasa = tgf_ccasa/cont_geral
                mgs_ccasa = tgf_cfora/cont_geral
                mgf_cfora = mgs_ccasa
                mgs_cfora = mgf_ccasa

                # carregando os times e o número de jogos de cada
                if cont1 < 10:
                    cont_ind[cont1] += 1
                    cont_ind[cont1+10] += 1
                    urc[cont1] = linha['HomeTeam']
                    urc[cont1+10] = linha['AwayTeam']
                    urf[cont1] = linha['HomeTeam']
                    urf[cont1+10] = linha['AwayTeam']

                    time[cont1] = {'time':linha['HomeTeam'],'num_jogosc':cont_ind[cont1],'num_jogosf':0,'tgf_tcasa':int(linha['FTHG']),'tgs_tcasa':int(linha['FTAG']),'tgf_tfora':0,'tgs_tfora':0,'mgf_tcasa':float(linha['FTHG'])/cont_ind[cont1],'mgs_tcasa':float(linha['FTAG'])/cont_ind[cont1],'mgf_tfora':0,'mgs_tfora':0}
                    time[cont1+10] = {'time':linha['AwayTeam'],'num_jogosc':0,'num_jogosf':cont_ind[cont1+10],'tgf_tcasa':0,'tgs_tcasa':0,'tgf_tfora':int(linha['FTAG']),'tgs_tfora':int(linha['FTHG']),'mgf_tcasa':0,'mgs_tcasa':0,'mgf_tfora':float(linha['FTAG'])/cont_ind[cont1+10],'mgs_tfora':float(linha['FTHG'])/cont_ind[cont1+10]}
                    cont1 += 1                  

                # contando jogos
                if cont_jogos <= 10:
                    cont_jogos += 1

                # atualizando os dados dos times por jogo
                if cont_geral >= 10:     
                    for i in range(20):
                        if linha['HomeTeam'] == time[i]['time']: 
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosc'] += 1
                            time[i]['tgf_tcasa'] += int(linha['FTHG'])
                            time[i]['tgs_tcasa'] += int(linha['FTAG'])

                            time[i]['mgf_tcasa'] = time[i]['tgf_tcasa']/time[i]['num_jogosc']
                            time[i]['mgs_tcasa'] = time[i]['tgs_tcasa']/time[i]['num_jogosc']

                        if linha['AwayTeam'] == time[i]['time']:
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosf'] += 1
                            time[i]['tgf_tfora'] += int(linha['FTAG'])
                            time[i]['tgs_tfora'] += int(linha['FTHG'])

                            time[i]['mgf_tfora'] = time[i]['tgf_tfora']/time[i]['num_jogosf']
                            time[i]['mgs_tfora'] = time[i]['tgs_tfora']/time[i]['num_jogosf']


                #contando rodadas - a primeira vez que entra aqui é a rodada 2
                if cont_jogos > 10 or dentro_rodada < 10:
                    # atualizando o número de rodadas
                    if cont_jogos > 10:
                        rodada += 1
                        cont_jogos = 1
                        dentro_rodada = 0



                    dentro_rodada += 1

                    #carregando times com dados da rodada para chamar o método
                    if rodada > 1:
                        for i in range(20):                 
                            if linha['HomeTeam'] == time[i]['time']:
                                time1_ant = time_ant[i] # time1 antes da rodada em questão
                                time1 = time[i]         # time1 depois da rodada em questão
                            if linha['AwayTeam'] == time[i]['time']:
                                time2_ant = time_ant[i] # time2 antes da rodada em questão
                                time2 = time[i]         # time2 depois da rodada em questão


                    #print('número de jogos: {}'.format(cont_geral))
                    # chamando o método para cálculo de probabilidades
                    
                    if rodada > 1:         
                        if odd_pca <= 1.7:
                            total_ja += 1
                            if int(linha['FTHG']) != 1 or int(linha['FTAG']) != 1:
                                if rs > mrs:
                                    mrs = rs
                                rs = 0
                                taxa_n1x0 += 1
                            else:
                                rs += 1
                                taxa_1x0 += 1
                                
                        '''elif odd_pfa <= 1.7:
                            total_ja += 1
                            if int(linha['FTHG']) != 0 or int(linha['FTAG']) != 1:
                                if rs > mrs:
                                    mrs = rs
                                rs = 0
                                taxa_n1x0 += 1
                            else:
                                rs += 1
                                taxa_1x0 += 1'''
                        pass
                                

                cont_geral += 1
            except:
                continue
                
    print(f'Campeonato: {camp}')
    print(f'Máximo de reds seguidos: {mrs}')
    return cont_geral - 1,taxa_n1x0,taxa_1x0,total_ja
        
    
# programa principal
# ano a ser avaliado
ent2 = input('Campeonato: ')
entrada2 = ent2.upper().split(',') # campeonato -> entrada2
tam_ent2 = len(entrada2)
print('\n')
entrada2 = entrada2

for i in range(tam_ent2):
    entrada2[i] +='.csv'


taxa_n1x0 = 0
taxa_1x0 = 0
total_ja = 0
num_jogos = 0

fnum_jogos = 0
ftaxa_n1x0 = 0
ftaxa_1x0 = 0
ftotal_ja = 0

ftaxa_al = []
ftaxa_ab = []

for i in range(tam_ent2):
    try:
        num_jogos,taxa_n1x0,taxa_1x0,total_ja = ano_dados(entrada2[i])
        fnum_jogos += num_jogos
        ftaxa_n1x0 += taxa_n1x0
        ftaxa_1x0 += taxa_1x0
        ftotal_ja += total_ja
        ftaxa_al.append((ftaxa_n1x0*100) / ftotal_ja)
        ftaxa_ab.append((ftaxa_1x0*100) / ftotal_ja)
        #print('Banca parcial {s:.2f}\n'.format(s = saldo_final))
    except:
        continue

#print(f'Número de entradas: {quant_entradas}   Saldo final: {saldo_final:.2f}')
odd_lay = 100 / (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))
odd_back = 100 / ((ftaxa_1x0 * 100) / (ftotal_ja))
so_odd_lay = 100 / (100 - st.median(ftaxa_al))
so_odd_back = 100 / st.median(ftaxa_ab)

print(f'\nTotal de jogos: {fnum_jogos}')
print(f'Total de jogos analisados: {ftotal_ja}\n')

print('taxa de 1x0: {} -> {t:.2f}%'.format(ftaxa_1x0,t = (ftaxa_1x0*100) / ftotal_ja))
print(f'taxa de 1x0 (tirando outliers): {st.median(ftaxa_ab):.2f}%')
print(f'Odd back ideal ACIMA de: {odd_back:.2f}')
print(f'Odd back ideal (tirando outliers) ACIMA de: {so_odd_back:.2f}\n')

print('taxa de nao 1x0: {} -> {tn:.2f}%'.format(ftaxa_n1x0,tn = (ftaxa_n1x0*100) / ftotal_ja))
print(f'taxa de não 1x0 (tirando outliers): {st.median(ftaxa_al):.2f}%')
print(f'Odd lay ideal ABAIXO de: {odd_lay:.2f}')
print(f'Odd lay ideal (tirando outliers) ABAIXO de: {so_odd_lay:.2f}\n')
# Out:
# Campeonato: t1,t2,t3,t4,t5,t6,t7,t8,t9,10,b10,b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,e1,e2,e3,e4,e5,e6,e7,ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8,ec9,f1,f2,f3,f4,f5,f6,f7,f8,f9,g,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,i1,i2,i3,i4,i5,i6,n1,n2,n3,n4,n5,n6,n7,n8,n9,p1,p2,p3,p4,p5,p6,p7,p8,p9,s1,s2,s3,s4,s5,s6,sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9
#
#
# Campeonato: T1.csv
# Máximo de reds seguidos: 1
# Campeonato: T2.csv
# Máximo de reds seguidos: 1
# Campeonato: T3.csv
# Máximo de reds seguidos: 1
# Campeonato: T4.csv
# Máximo de reds seguidos: 1
# Campeonato: T5.csv
# Máximo de reds seguidos: 1
# Campeonato: T6.csv
# Máximo de reds seguidos: 1
# Campeonato: T7.csv
# Máximo de reds seguidos: 1
# Campeonato: T8.csv
# Máximo de reds seguidos: 0
# Campeonato: T9.csv
# Máximo de reds seguidos: 0
# Campeonato: B10.csv
# Máximo de reds seguidos: 0
# Campeonato: B1.csv
# Máximo de reds seguidos: 0
# Campeonato: B2.csv
# Máximo de reds seguidos: 1
# Campeonato: B3.csv
# Máximo de reds seguidos: 1
# Campeonato: B4.csv
# Máximo de reds seguidos: 1
# Campeonato: B5.csv
# Máximo de reds seguidos: 1
# Campeonato: B6.csv
# Máximo de reds seguidos: 2
# Campeonato: B7.csv
# Máximo de reds seguidos: 0
# Campeonato: B8.csv
# Máximo de reds seguidos: 1
# Campeonato: B9.csv
# Máximo de reds seguidos: 0
# Campeonato: B10.csv
# Máximo de reds seguidos: 0
# Campeonato: D1.csv
# Máximo de reds seguidos: 1
# Campeonato: D2.csv
# Máximo de reds seguidos: 1
# Campeonato: D3.csv
# Máximo de reds seguidos: 1
# Campeonato: D4.csv
# Máximo de reds seguidos: 1
# Campeonato: D5.csv
# Máximo de reds seguidos: 2
# Campeonato: D6.csv
# Máximo de reds seguidos: 1
# Campeonato: D7.csv
# Máximo de reds seguidos: 2
# Campeonato: D8.csv
# Máximo de reds seguidos: 0
# Campeonato: D9.csv
# Máximo de reds seguidos: 0
# Campeonato: E1.csv
# Máximo de reds seguidos: 1
# Campeonato: E2.csv
# Máximo de reds seguidos: 1
# Campeonato: E3.csv
# Máximo de reds seguidos: 1
# Campeonato: E4.csv
# Máximo de reds seguidos: 1
# Campeonato: E5.csv
# Máximo de reds seguidos: 1
# Campeonato: E6.csv
# Máximo de reds seguidos: 1
# Campeonato: E7.csv
# Máximo de reds seguidos: 1
# Campeonato: EC1.csv
# Máximo de reds seguidos: 2
# Campeonato: EC2.csv
# Máximo de reds seguidos: 1
# Campeonato: EC3.csv
# Máximo de reds seguidos: 2
# Campeonato: EC4.csv
# Máximo de reds seguidos: 3
# Campeonato: EC5.csv
# Máximo de reds seguidos: 2
# Campeonato: EC6.csv
# Máximo de reds seguidos: 1
# Campeonato: EC7.csv
# Máximo de reds seguidos: 2
# Campeonato: EC8.csv
# Máximo de reds seguidos: 0
# Campeonato: EC9.csv
# Máximo de reds seguidos: 0
# Campeonato: F1.csv
# Máximo de reds seguidos: 3
# Campeonato: F2.csv
# Máximo de reds seguidos: 1
# Campeonato: F3.csv
# Máximo de reds seguidos: 1
# Campeonato: F4.csv
# Máximo de reds seguidos: 1
# Campeonato: F5.csv
# Máximo de reds seguidos: 1
# Campeonato: F6.csv
# Máximo de reds seguidos: 1
# Campeonato: F7.csv
# Máximo de reds seguidos: 1
# Campeonato: F8.csv
# Máximo de reds seguidos: 0
# Campeonato: F9.csv
# Máximo de reds seguidos: 0
# Campeonato: G.csv
# Máximo de reds seguidos: 0
# Campeonato: G1.csv
# Máximo de reds seguidos: 1
# Campeonato: G3.csv
# Máximo de reds seguidos: 0
# Campeonato: G4.csv
# Máximo de reds seguidos: 1
# Campeonato: G5.csv
# Máximo de reds seguidos: 1
# Campeonato: G6.csv
# Máximo de reds seguidos: 1
# Campeonato: G7.csv
# Máximo de reds seguidos: 1
# Campeonato: G9.csv
# Máximo de reds seguidos: 0
# Campeonato: G10.csv
# Máximo de reds seguidos: 0
# Campeonato: I1.csv
# Máximo de reds seguidos: 1
# Campeonato: I2.csv
# Máximo de reds seguidos: 2
# Campeonato: I3.csv
# Máximo de reds seguidos: 2
# Campeonato: I4.csv
# Máximo de reds seguidos: 2
# Campeonato: I5.csv
# Máximo de reds seguidos: 1
# Campeonato: I6.csv
# Máximo de reds seguidos: 3
# Campeonato: N1.csv
# Máximo de reds seguidos: 1
# Campeonato: N2.csv
# Máximo de reds seguidos: 1
# Campeonato: N3.csv
# Máximo de reds seguidos: 2
# Campeonato: N4.csv
# Máximo de reds seguidos: 2
# Campeonato: N5.csv
# Máximo de reds seguidos: 1
# Campeonato: N6.csv
# Máximo de reds seguidos: 1
# Campeonato: N7.csv
# Máximo de reds seguidos: 1
# Campeonato: N8.csv
# Máximo de reds seguidos: 0
# Campeonato: N9.csv
# Máximo de reds seguidos: 0
# Campeonato: P1.csv
# Máximo de reds seguidos: 1
# Campeonato: P2.csv
# Máximo de reds seguidos: 1
# Campeonato: P3.csv
# Máximo de reds seguidos: 1
# Campeonato: P4.csv
# Máximo de reds seguidos: 1
# Campeonato: P5.csv
# Máximo de reds seguidos: 1
# Campeonato: P6.csv
# Máximo de reds seguidos: 2
# Campeonato: P7.csv
# Máximo de reds seguidos: 1
# Campeonato: P8.csv
# Máximo de reds seguidos: 0
# Campeonato: P9.csv
# Máximo de reds seguidos: 0
# Campeonato: S1.csv
# Máximo de reds seguidos: 1
# Campeonato: S2.csv
# Máximo de reds seguidos: 1
# Campeonato: S3.csv
# Máximo de reds seguidos: 2
# Campeonato: S4.csv
# Máximo de reds seguidos: 2
# Campeonato: S5.csv
# Máximo de reds seguidos: 2
# Campeonato: S6.csv
# Máximo de reds seguidos: 1
# Campeonato: SC2.csv
# Máximo de reds seguidos: 0
# Campeonato: SC3.csv
# Máximo de reds seguidos: 1
# Campeonato: SC4.csv
# Máximo de reds seguidos: 1
# Campeonato: SC5.csv
# Máximo de reds seguidos: 1
# Campeonato: SC6.csv
# Máximo de reds seguidos: 1
# Campeonato: SC7.csv
# Máximo de reds seguidos: 1
# Campeonato: SC8.csv
# Máximo de reds seguidos: 0
# Campeonato: SC9.csv
# Máximo de reds seguidos: 0
#
# Total de jogos: 26583
# Total de jogos analisados: 4288
#
# taxa de 1x0: 338 -> 7.88%
# taxa de 1x0 (tirando outliers): 7.88%
# Odd back ideal ACIMA de: 12.69
# Odd back ideal (tirando outliers) ACIMA de: 12.69
#
# taxa de nao 1x0: 3950 -> 92.12%
# taxa de não 1x0 (tirando outliers): 92.12%
# Odd lay ideal ABAIXO de: 12.69
# Odd lay ideal (tirando outliers) ABAIXO de: 12.69

# %%
#t1,t2,t3,t4,t5,t6,t7,t8,t9,10,b10,b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,e1,e2,e3,e4,e5,e6,e7,ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8,ec9,f1,f2,f3,f4,f5,f6,f7,f8,f9,g,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,i1,i2,i3,i4,i5,i6,n1,n2,n3,n4,n5,n6,n7,n8,n9,p1,p2,p3,p4,p5,p6,p7,p8,p9,s1,s2,s3,s4,s5,s6,sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9

# %%
# s1,s2,s3,s4,s5,s6,d1,d2,d3,d4,d5,d6,i1,i2,i3,i4,i5,i6,e1,e2,e3,e4,e5,e6
