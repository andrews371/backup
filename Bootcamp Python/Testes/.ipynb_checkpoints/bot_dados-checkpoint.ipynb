# %%
import csv
import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver

gecko = '/home/andre/Downloads/geckodriver'
driver = webdriver.FirefoxOptions()
driver.add_argument('-headless')
driver = webdriver.Firefox(executable_path=gecko, options=driver)

url = 'https://www.betfair.com/br'
driver.get(url)
time.sleep(3)
elemento = driver.find_element_by_xpath('//*[@id="ssc-liu"]')
elemento.send_keys('aoliveira371@gmail.com')
elemento = driver.find_element_by_xpath('//*[@id="ssc-lipw"]')
elemento.send_keys('ao300887')
elemento.submit()

for i in range(6):
    url = 'https://www.betfair.com/exchange/plus/football/market/1.162285065'
    driver.get(url)
    time.sleep(10)
    html = driver.execute_script("return document.documentElement.outerHTML")
    page = bs(html, 'html.parser')
    a1 = page.find(class_='back-selection-button').find(class_='bet-button-price').text
    a2 = page.find(class_='lay-selection-button').find(class_='bet-button-price').text
    with open('Dados_Futebol.csv', 'a', encoding='utf-8', newline='') as acsv:
        arq = csv.writer(acsv)
        arq.writerow([a1,a2])
    time.sleep(5)    
    
driver.quit()

# %%
# Aqui mesmo a página usando javascript conseguimos fazer web scraping 
# para isso usamos o selenium
# Aqui não abrimos o firefox

import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

# descomentar estas 4 próximas linhas para usar o navegador invisível
#gecko = '/home/andre/Downloads/geckodriver'
#driver = webdriver.FirefoxOptions()
#driver.add_argument('-headless')
#driver = webdriver.Firefox(executable_path=gecko, options=driver)

url = 'https://www.sofascore.com/pt/torneio/futebol/brazil/brasileiro-serie-a/325'
url_inicio = 'https://www.sofascore.com'

# comentar a linha abaixo se for usar o navegador invisível
driver = webdriver.Firefox() 
driver.get(url)
time.sleep(1)

# Informações de país e campeonato
pais = driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[1]/div[2]/div[1]/a/span').text
campeonato = driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[1]/div[2]/div[2]/h2').text

# clicando no menu para escolha do ano
driver.find_element_by_css_selector('.u-pos-absolute > div:nth-child(1) > div:nth-child(1) > button:nth-child(1) > span:nth-child(1)').click()
time.sleep(1)

# Para mudar de temporada começar mudando o armazenamento do ano abaixo
# e depois mudar o ano de fato

# armazenando o ano - começando com 2016
ano = driver.find_element_by_css_selector('.dropdown__menu--scroll > li:nth-child(4) > a:nth-child(1)').text

# escolhendo o ano - começando com 2016
driver.find_element_by_css_selector('.dropdown__menu--scroll > li:nth-child(4) > a:nth-child(1)').click()
time.sleep(2)

# classificando por rodadas
driver.find_element_by_css_selector('.js-tournament-page-events-select-round').click()
time.sleep(1)

# varrendo as 38 rodadas
i = 0
if i == 0:        
    # clicando no menu para escolha da rodada
    driver.find_element_by_css_selector('.js-select-events-by-round-container > div:nth-child(2) > div:nth-child(1) > div:nth-child(1) > button:nth-child(1) > span:nth-child(1)').click()
    time.sleep(1)
    
    # escolhendo a rodada 1              
    driver.find_element_by_css_selector('.js-select-round-dropdown > li:nth-child(1) > a:nth-child(1)').click()
    time.sleep(1)
    
    # rolar a página mais para baixo
    body = driver.find_element_by_css_selector('body')
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)

    html = driver.execute_script("return document.documentElement.outerHTML")
    page = bs(html, 'html.parser')
    
    possebola = 'Posse de bola'
    chutes = 'Finalizações'
    chutesnogol = 'Finalizações no gol'
    chutesforagol = 'Finalizações para fora'
    chutesbloqueados = 'Chutes travados'
    corner = 'Escanteios'
    impedimentos = 'Impedimentos'
    faltas = 'Faltas'
    cartoesa = 'Cartões amarelos'
    cartoesv = 'Cartões vermelhos'
    grandeschances = 'Grandes chances'
    grandeschancesperdidas = 'Grandes chances perdidas'
    chutesnatrave = 'Finalizações na trave'
    contraataques = 'Contra-ataques'
    chutesdentroarea = 'Finalizações de dentro da área'
    chutesforaarea = 'Finalizações de fora da área'
    defesasgoleiro = 'Defesas do goleiro'
    passes = 'Passes'
    passescertos = 'Passes certos'
    bolaslongas = 'Bolas longas'
    cruza = 'Cruzamentos'
    dribles = 'Dribles'
    posseperdida = 'Possession lost'
    duelosganhos = 'Duelos ganhos'
    disputasaereasvencidas = 'Disputas aéreas vencidas'
    desarmes = 'Desarmes'
    intercept = 'Interceptações'
    cortes = 'Cortes'
        
    # Percorrendo todas as rodadas
    for i in range(1):
        
        # contando o número de jogos da rodada
        for k in range(5): # conto até 5 pq tem outros elementos com este nome de classe
            try:
                tam = len(page.find_all('',{'class':'js-event-list-tournament-events'})[k].find_all('a'))
                if (tam >= 3):
                    break
            except:
                continue
                
        # Percorrendo todos os jogos da rodada
        for j in range(tam):
            try:
                
                # Inicialização de variáveis relacionadas à gols e minuto de gols
                gol1jogomin = -1
                gol2jogomin = -1  
                gol3jogomin = -1
                gol4jogomin = -1
                gol5jogomin = -1
                gol6jogomin = -1
                gol7jogomin = -1
                gol8jogomin = -1
                gol9jogomin = -1
                gol10jogomin = -1
                gol11jogomin = -1
                gol12jogomin = -1
                gol13jogomin = -1

                gol1jogotime = ''
                gol2jogotime = ''
                gol3jogotime = ''
                gol4jogotime = ''
                gol5jogotime = ''
                gol6jogotime = ''
                gol7jogotime = ''
                gol8jogotime = ''
                gol9jogotime = ''
                gol10jogotime = ''
                gol11jogotime = ''
                gol12jogotime = ''
                gol13jogotime = ''

                gol1time1min = -1
                gol2time1min = -1
                gol3time1min = -1
                gol4time1min = -1
                gol5time1min = -1
                gol6time1min = -1
                gol7time1min = -1
                gol8time1min = -1
                gol9time1min = -1
                gol10time1min = -1

                gol1time2min = -1
                gol2time2min = -1
                gol3time2min = -1
                gol4time2min = -1
                gol5time2min = -1
                gol6time2min = -1
                gol7time2min = -1
                gol8time2min = -1
                gol9time2min = -1
                gol10time2min = -1
                
                mingol = []
                
                # clicando nos jogos
                var1 = str(1 + j)
                driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[3]/div[3]/div/div[1]/div[3]/div[2]/div/div/div[3]/div[2]/div[2]/a['+var1+']').click()
                time.sleep(5)                 
                
                estatisticas_ht_ft = False
                
                # pegando o nome dos times
                time1 = driver.find_element_by_css_selector('.h-interactive > span:nth-child(1)').text
                time2 = driver.find_element_by_css_selector('.h-interactive > span:nth-child(2)').text
                
                # Abrindo página com os dados da partida
                driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div/div/div[1]/div[3]/div[3]/div/div[2]/div/div/div[1]/div[1]/a').click()
                time.sleep(5)
                
                # Coletando informações do jogo                      
                data = driver.find_element_by_css_selector('.cell--start > div:nth-child(1) > div:nth-child(1)').text  
                resultadoft = driver.find_element_by_css_selector('.details__score-cell > div:nth-child(2) > div:nth-child(1)').text.strip()
                golscasaft = resultadoft[0]                       
                golsvisitanteft = resultadoft[4]
                resultadoht = driver.find_element_by_css_selector('.details__score-cell > div:nth-child(2) > div:nth-child(2)').text.strip()
                golscasaht = resultadoht[1]
                golsvisitanteht = resultadoht[5]
                golscasa2t = int(golscasaft) - int(golscasaht)
                golsvisitante2t = int(golsvisitanteft) - int(golsvisitanteht)
                
                print(pais)                             
                print(campeonato)
                print(ano)
                print(data)
                print(time1)
                print(time2)
                
                # mudar para a aba aberta
                driver.switch_to.window(driver.window_handles[1])
                
                # rolar a página mais para baixo
                body = driver.find_element_by_css_selector('body')
                body.send_keys(Keys.PAGE_DOWN)
                time.sleep(1) 
                            
                html = driver.execute_script("return document.documentElement.outerHTML")
                page = bs(html, 'html.parser')
                
                
                # aqui começa a coleta de minuto de 1o gol 2o gol, placar em 5 e 5 min, quem fez o 1o
                # o 2o gol do jogo              
                
                # contando quantos gols aconteceram no jogo
                #tam_placar = len(page.find_all('',{'class':'incident__goal'}))
                
                # contando quantos gols cada time fez
                tam_minutogol1 = len(page.find('div',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '}))
                tam_minutogol2 = len(page.find('div',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '}))
                tam_placar = tam_minutogol1 + tam_minutogol2
                # coletando o minuto dos gols
                
                # minuto que o placar mudou e novo placar
                for totalgols in range(tam_placar):
                    try:
                        placarpormingol = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '})[totalgols].find('span',{'class':'incident__goal'}).text.strip()
                        print(placarpormingol)
                        mingol.append(page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '})[totalgols].find('',{'cell__content incident__time'}).text.strip().split("'")[0])
                        print(f'minuto do gol: {mingol}')
                    except:
                        pass
                    try:
                        placarmingol = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '})[totalgols].find('span',{'class':'incident__goal'}).text.strip()
                        print(placarpormingol)
                        mingol.append(page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '})[totalgols].find('',{'cell__content incident__time'}).text.strip().split("'")[0])
                        print(f'minuto do gol: {mingol}')
                    except:
                        continue
                    
                    '''# gols do time 1
                    for minutosgols in range(tam_minutogol):
                        try:
                            teste = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '})[minutosgols].find('span',{'class':'incident__goal'}).text.strip()
                            minutogol = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--incident '})[minutosgols].find('',{'cell__content incident__time'}).text.strip().split("'")[0]
                            print(f'minuto do gol: {minutogol}')
                        except:
                            continue

                    # gols do time 2       
                    for minutosgols2 in range(tam_minutogol2):
                        try:
                            teste2 = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '})[minutosgols2].find('span',{'class':'incident__goal'}).text.strip()
                            minutogol2 = page.find('',{'class':'js-event-page-incidents-container'}).find_all('',{'class':'cell cell--right cell--incident '})[minutosgols2].find('',{'cell__content incident__time'}).text.strip().split("'")[0]
                            print(f'minuto do gol 2: {minutogol2}')
                        except:
                            continue'''
                    pass
                    
                    
                
                '''# Pegando as estatísticas de cada jogo no ft, ht e 2o tempo
                for intervalos in range(3):
                    if intervalos == 0: # para dados no ft
                        for blocos in range(7):
                            bloco1 = str(1 + blocos)
                            for estatisticas in range(7):
                                bloco2 = str(1 + estatisticas)
                                try:
                                    # obtendo dados FT            
                                    driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div[1]/div[11]/div/ul/li[1]/a').click()
                                    
                                    # verificar se o jogo em questão possui estatísticas ht e ft
                                    estatisticas_ht_ft = True
                                    
                                    nome_dado = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(2) > div:nth-child(1)').text
                                    print(f'oi {nome_dado}')
                                    print(f'blocos {bloco1} estatisitcas {bloco2}')
                                    
                                    if nome_dado.strip() == possebola:
                       
                                        possebolacasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        possebolavisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(possebolacasaft)
                                        print(possebolavisitanteft)

                                    elif nome_dado.strip() == chutes:

                                        chutescasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutescasaft)
                                        print(chutesvisitanteft)
                                       

                                    elif nome_dado.strip() == chutesnogol:
                                        
                                        chutesnogolcasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesnogolvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text
                            
                                        print(nome_dado)
                                        print(chutesnogolcasaft)
                                        print(chutesnogolvisitanteft)
                                        

                                    elif nome_dado.strip() == chutesforagol:
                                        
                                        chutesforagolcasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesforagolvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesforagolcasaft)
                                        print(chutesforagolvisitanteft)
                                        

                                    elif nome_dado.strip() == chutesbloqueados:
                                        
                                        chutesbloqueadoscasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesbloqueadosvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesbloqueadoscasaft)
                                        print(chutesbloqueadosvisitanteft)
                                        

                                    elif nome_dado.strip() == corner: 
                                        
                                        cornercasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cornervisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text
                                        
                                        print(nome_dado)                            
                                        print(cornercasaft)
                                        print(cornervisitanteft)
                                        

                                    elif nome_dado.strip() == impedimentos:
                                        
                                        impedimentoscasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        impedimentosvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(impedimentoscasaft)
                                        print(impedimentosvisitanteft)
                                        

                                    elif nome_dado.strip() == faltas:
                                        
                                        faltascasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        faltasvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(faltascasaft)
                                        print(faltasvisitanteft)
                                        
                                    elif nome_dado.strip() == cartoesa:
                                        
                                        cartoesacasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cartoesavisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cartoesacasaft)
                                        print(cartoesavisitanteft)
                                        
                                    elif nome_dado.strip() == cartoesv:
                                                                                            
                                        cartoesvcasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cartoesvvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cartoesvcasaft)
                                        print(cartoesvvisitanteft)
                                        

                                    elif nome_dado.strip() == grandeschances:
                                        
                                        grandeschancescasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        grandeschancesvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(grandeschancescasaft)
                                        print(grandeschancesvisitanteft)
                                       

                                    elif nome_dado.strip() == grandeschancesperdidas:
                                        
                                        grandeschancesperdidascasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        grandeschancesperdidasvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(grandeschancesperdidascasaft)
                                        print(grandeschancesperdidasvisitantft)
                                        

                                    elif nome_dado.strip() == chutesnatrave:
                                        
                                        chutesnatravecasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesnatravevisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesnatravecasaft)
                                        print(chutesnatravevisitanteft)
                                        
                                    elif nome_dado.strip() == contraataques:
                                        
                                        contraataquescasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        contraataquesvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(contraataquescasaft)
                                        print(contraataquesvisitanteft)
                                        
                                    elif nome_dado.strip() == chutesdentroarea:
                                        
                                        chutesdentroareacasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesdentroareavisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesdentroareacasaft)
                                        print(chutesdentroareavisitanteft)
                                        
                                    elif nome_dado.strip() == chutesforaarea:
                                        
                                        chutesforaareacasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesforaareavisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesforaareacasaft)
                                        print(chutesforaareavisitanteft)
                                        

                                    elif nome_dado.strip() == defesasgoleiro:
                                        
                                        defesasgoleirocasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        defesasgoleirovisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(defesasgoleirocasaft)
                                        print(defesasgoleirovisitanteft)

                                    elif nome_dado.strip() == passes:
                                        
                                        passescasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        passesvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(passescasaft)
                                        print(passesvisitanteft)
                                        
                                    elif nome_dado.strip() == passescertos:
                                        
                                        passescertoscasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        passescertosvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(passescertoscasaft)
                                        print(passescertosvisitanteft)
                                        

                                    elif nome_dado.strip() == bolaslongas:
                                        
                                        bolaslongascasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        bolaslongasvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(bolaslongascasaft)
                                        print(bolaslongasvisitanteft)
                                        

                                    elif nome_dado.strip() == cruza:
                                        
                                        cruzacasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cruzavisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cruzacasaft)
                                        print(curzavisitanteft)
                                        

                                    elif nome_dado.strip() == dribles:
                                        
                                        driblescasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        driblesvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(driblescasaft)
                                        print(driblesvisitanteft)
                                        

                                    elif nome_dado.strip() == posseperdida:
                                        
                                        posseperdidacasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        posseperdidavisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(posseperdidacasaft)
                                        print(posseperdidavisitanteft)
                                        

                                    elif nome_dado.strip() == duelosganhos:
                                        
                                        duelosganhoscasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        duelosganhosvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(duelosganhoscasaft)
                                        print(duelosganhosvisitanteft)
                                        
                                    elif nome_dado.strip() == disputasaereasvencidas:
                                        
                                        disputasaereasvencidascasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        disputasaereasvencidasvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(disputasaereasvencidascasaft)
                                        print(disputasaereasvencidasvisitanteft)
                                        
                                    elif nome_dado.strip() == desarmes:
                                        
                                        desarmescasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        desarmesvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(desarmescasaft)
                                        print(desarmesvisitanteft)
                                        

                                    elif nome_dado.strip() == intercept:
                                        
                                        interceptcasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        interceptvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(interceptcasaft)
                                        print(interceptvisitanteft)
                                        
                                    elif nome_dado.strip() == cortes:
                                        
                                        cortescasaft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cortesvisitanteft = driver.find_element_by_css_selector('#statistics-period-ALL > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cortescasaft)
                                        print(cortesvisitanteft)
                                       

                                except:
                                    continue
                        
                        if estatisticas_ht_ft == True and blocos == 6 and estatisticas == 6:
                            print(golscasaft)
                            print(golsvisitanteft)
                        
                    elif intervalos == 1:
                        for blocos in range(7):
                            bloco1 = str(1 + blocos)
                            for estatisticas in range(7):
                                bloco2 = str(1 + estatisticas)
                                try:
                                    # obtendo dados do 1o tempo   
                                    driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div[1]/div[11]/div/ul/li[2]/a').click()
                                    nome_dado = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(2) > div:nth-child(1)').text
                                    print(f'oi {nome_dado}')
                                    print(f'blocos {bloco1} estatisitcas {bloco2}')
                                   
                                    if nome_dado.strip() == possebola:
                                                                                                
                                        possebolacasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        possebolavisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)                                
                                        print(possebolacasaht)
                                        print(possebolavisitanteht)
                                        

                                    elif nome_dado.strip() == chutes:

                                        chutescasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)  
                                        print(chutescasaht)
                                        print(chutesvisitanteht)
                                        
                                    elif nome_dado.strip() == chutesnogol:

                                        chutesnogolcasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesnogolvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesnogolcasaht)
                                        print(chutesnogolvisitanteht)
                                        

                                    elif nome_dado.strip() == chutesforagol:

                                        chutesforagolcasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesforagolvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesforagolcasaht)
                                        print(chutesforagolvisitanteht)
                                        

                                    elif nome_dado.strip() == chutesbloqueados:

                                        chutesbloqueadoscasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesbloqueadosvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text
                                        
                                        print(nome_dado)
                                        print(chutesbloqueadoscasaht)
                                        print(chutesbloqueadosvisitanteht)
                                        
                                    elif nome_dado.strip() == corner: 
                                        
                                        cornercasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cornervisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)                            
                                        print(cornercasaht)
                                        print(cornervisitanteht)
                                        
                                    elif nome_dado.strip() == impedimentos:

                                        impedimentoscasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        impedimentosvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(impedimentoscasaht)
                                        print(impedimentosvisitanteht)
                                        

                                    elif nome_dado.strip() == faltas:

                                        faltascasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        faltasvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(faltascasaht)
                                        print(faltasvisitanteht)
                                        

                                    elif nome_dado.strip() == cartoesa:

                                        cartoesacasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cartoesavisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cartoesacasaht)
                                        print(cartoesavisitanteht)
                                        

                                    elif nome_dado.strip() == cartoesv:

                                        cartoesvcasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cartoesvvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cartoesvcasaht)
                                        print(cartoesvvisitanteht)
                                        

                                    elif nome_dado.strip() == grandeschances:

                                        grandeschancescasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        grandeschancesvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(grandeschancescasaht)
                                        print(grandeschancesvisitanteht)
                                        
                                    elif nome_dado.strip() == grandeschancesperdidas:

                                        grandeschancesperdidascasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        grandeschancesperdidasvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(granceschancesperdidascasaht)
                                        print(grandeschancesperdidasvisitanteht)
                                        
                                    elif nome_dado.strip() == chutesnatrave:

                                        chutesnatravecasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesnatravevisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesnatravecasaht)
                                        print(chutesnatravevisitanteht)
                                        

                                    elif nome_dado.strip() == contraataques:

                                        contraataquescasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        contraataquesvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(contraataquescasaht)
                                        print(contraataquesvisitanteht)
                                        

                                    elif nome_dado.strip() == chutesdentroarea:

                                        chutesdentroareacasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesdentroareavisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesdentroareacasaht)
                                        print(chutesdentroareavisitanteht)
                                        
                                    elif nome_dado.strip() == chutesforaarea:

                                        chutesforaareacasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesforaareavisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesforaareacasaht)
                                        print(chutesforaareavisitanteht)
                                        
                                    elif nome_dado.strip() == defesasgoleiro:

                                        defesasgoleirocasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        defesasgoleirovisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(defesasgoleirocasaht)
                                        print(defesasgoleirovisitanteht)
                                        

                                    elif nome_dado.strip() == passes:

                                        passescasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        passesvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(passescasaht)
                                        print(passesvisitanteht)
                                        

                                    elif nome_dado.strip() == passescertos:

                                        passescertoscasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        passescertosvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(passescertoscasaht)
                                        print(passescertosvisitanteht)
                                        
                                    elif nome_dado.strip() == bolaslongas:

                                        bolaslongascasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        bolaslongasvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(bolaslongascasaht)
                                        print(bolaslongasvisitanteht)
                                        
                                    elif nome_dado.strip() == cruza:

                                        cruzacasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cruzavisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cruzacasaht)
                                        print(cruzavisitanteht)
                                        

                                    elif nome_dado.strip() == dribles:

                                        driblescasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        driblesvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(driblescasaht)
                                        print(driblesvisitanteht)
                                        

                                    elif nome_dado.strip() == posseperdida:

                                        posseperdidacasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        posseperdidavisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(posseperdidacasaht)
                                        print(posseperdidavisitanteht)
                                        

                                    elif nome_dado.strip() == duelosganhos:

                                        duelosganhoscasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        duelosganhosvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(duelosganhoscasaht)
                                        print(duelosganhosvisitanteht)
                                       

                                    elif nome_dado.strip() == disputasaereasvencidas:

                                        disputasaereasvencidascasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        disputasaereasvencidasvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(disputasaereasvencidascasaht)
                                        print(disputasaereasvencidasvisitanteht)
                                        
                                    elif nome_dado.strip() == desarmes:

                                        desarmescasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        desarmesvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(desarmescasaht)
                                        print(desarmesvisitanteht)
                                        
                                    elif nome_dado.strip() == intercept:

                                        interceptcasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        interceptvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(interceptcasaht)
                                        print(interceptvisitanteht)
                                        
                                    elif nome_dado.strip() == cortes:

                                        cortescasaht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cortesvisitanteht = driver.find_element_by_css_selector('#statistics-period-1ST > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cortescasaht)
                                        print(cortesvisitanteht)
                                        
                                except:
                                    continue
                        
                        if estatisticas_ht_ft == True and blocos == 6 and estatisticas == 6:
                            print(golscasaht)
                            print(golsvisitanteht)
                        
                    else:
                        for blocos in range(7):
                            bloco1 = str(1 + blocos)
                            for estatisticas in range(7):
                                bloco2 = str(1 + estatisticas)
                                try:
                                    
                                    # obtendo dados do 2o tempo
                                    driver.find_element_by_xpath('/html/body/div[5]/div/div[2]/div/div[1]/div[11]/div/ul/li[3]/a').click()
                                    nome_dado = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(2) > div:nth-child(1)').text
                                    print(f'oi {nome_dado}')
                                    print(f'blocos {bloco1} estatisitcas {bloco2}')
                                    
                                    if nome_dado.strip() == possebola:

                                        possebolacasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        possebolavisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)                                       
                                        print(possebolacasa2t)
                                        print(possebolavisitante2t)

                                    elif nome_dado.strip() == chutes:

                                        chutescasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)                                        
                                        print(chutescasa2t)
                                        print(chutesvisitante2t)

                                    elif nome_dado.strip() == chutesnogol:

                                        chutesnogolcasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesnogolvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesnogolcasa2t)
                                        print(chutesnogolvisitante2t)

                                    elif nome_dado.strip() == chutesforagol:

                                        chutesforagolcasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesforagolvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesforagolcasa2t)
                                        print(chutesforagolvisitante2t)

                                    elif nome_dado.strip() == chutesbloqueados:

                                        chutesbloqueadoscasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesbloqueadosvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesbloqueadoscasa2t)
                                        print(chutesbloqueadosvisitante2t)

                                    elif nome_dado.strip() == corner: 

                                        cornercasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cornervisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)                            
                                        print(cornercasa2t)
                                        print(cornervisitante2t)

                                    elif nome_dado.strip() == impedimentos:

                                        impedimentoscasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        impedimentosvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)                                        
                                        print(impedimentoscasa2t)
                                        print(impedimentosvisitante2t)

                                    elif nome_dado.strip() == faltas:

                                        faltascasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        faltasvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(faltascasa2t)
                                        print(faltasvisitante2t)

                                    elif nome_dado.strip() == cartoesa:

                                        cartoesacasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cartoesavisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cartoesacasa2t)
                                        print(cartoesavisitante2t)

                                    elif nome_dado.strip() == cartoesv:
                                                                                                
                                        cartoesvcasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cartoesvvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cartoesvcasa2t)
                                        print(cartoesvvisitante2t)

                                    elif nome_dado.strip() == grandeschances:

                                        grandeschancescasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        grandeschancesvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(grandeschancescasa2t)
                                        print(grandeschancesvisitante2t)

                                    elif nome_dado.strip() == grandeschancesperdidas:

                                        grandeschancesperdidascasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        grandeschancesperdidasvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(grandeschancesperdidascasa2t)
                                        print(grandeschancesperdidasvisitante2t)

                                    elif nome_dado.strip() == chutesnatrave:

                                        chutesnatravecasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesnatravevisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesnatravecasa2t)
                                        print(chutesnatravevisitante2t)

                                    elif nome_dado.strip() == contraataques:

                                        contraataquescasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        contraataquesvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(contraataquescasa2t)
                                        print(contaataquesvisitante2t)

                                    elif nome_dado.strip() == chutesdentroarea:

                                        chutesdentroareacasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesdentroareavisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesdentroareacasa2t)
                                        print(chutesdentroareavisitante2t)

                                    elif nome_dado.strip() == chutesforaarea:

                                        chutesforaareacasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        chutesforaareavisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(chutesforaareacasa2t)
                                        print(chutesforaareavisitante2t)

                                    elif nome_dado.strip() == defesasgoleiro:

                                        defesasgoleirocasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        defesasgoleirovisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(defesasgoleirocasa2t)
                                        print(defesasgoleirovisitante2t)

                                    elif nome_dado.strip() == passes:

                                        passescasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        passesvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(passescasa2t)
                                        print(passesvisitante2t)

                                    elif nome_dado.strip() == passescertos:

                                        passescertoscasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        passescertosvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(passescertoscasa2t)
                                        print(passescertosvisitante2t)

                                    elif nome_dado.strip() == bolaslongas:

                                        bolaslongascasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        bolaslongasvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(bolaslongascasa2t)
                                        print(bolaslongasvisitante2t)

                                    elif nome_dado.strip() == cruza:

                                        cruzacasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cruzavisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cruzacasa2t)
                                        print(cruzavisitante2t)

                                    elif nome_dado.strip() == dribles:

                                        driblescasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        driblesvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(driblescasa2t)
                                        print(driblesvisitante2t)

                                    elif nome_dado.strip() == posseperdida:

                                        posseperdidacasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        posseperdidavisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(posseperdidacasa2t)
                                        print(posseperdidavisitante2t)

                                    elif nome_dado.strip() == duelosganhos:

                                        duelosganhoscasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        duelosganhosvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(duelosganhoscasa2t)
                                        print(duelosganhosvisitante2t)

                                    elif nome_dado.strip() == disputasaereasvencidas:

                                        disputasaereasvencidascasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        disputasaereasvencidasvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(disputasaereasvencidascasa2t)
                                        print(disputasaereasvencidasvisitante2t)

                                    elif nome_dado.strip() == desarmes:

                                        desarmescasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        desarmesvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(desarmescasa2t)
                                        print(desarmesvisitante2t)

                                    elif nome_dado.strip() == intercept:

                                        interceptcasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        interceptvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(inteceptcasa2t)
                                        print(interceptvisitante2t)

                                    elif nome_dado.strip() == cortes:

                                        cortescasa2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(1) > div:nth-child(1)').text
                                        cortesvisitante2t = driver.find_element_by_css_selector('#statistics-period-2ND > div:nth-child('+ bloco1 +') > div:nth-child('+ bloco2 +') > div:nth-child(3) > div:nth-child(1)').text

                                        print(nome_dado)
                                        print(cortescasa2t)
                                        print(cortesvisitante2t)

                                except:
                                    continue
                        
                        if estatisticas_ht_ft == True and blocos == 6 and estatisticas == 6:
                            print(golscasa2t)
                            print(golsvisitante2t)'''
                pass
                            
                
                # para fechar a aba do jogo que se está nela 
                driver.close()
                
                # mudar para a aba aberta - página principal 
                driver.switch_to.window(driver.window_handles[0])
            except:
                continue
            
else:
    # clicando em próxima rodada
    driver.find_element_by_css_selector('.js-tournament-page-show-next-round > span:nth-child(1)').click()


#driver.quit() # fecha o navegador que estava aberto e invisível
# Out:
# Brasil
# Brasileiro Série A
# 2016
# 14. Mai 2016, 16:00
# Flamengo
# Sport Recife
# 1 - 0
# minuto do gol: ['5']
# Brasil
# Brasileiro Série A
# 2016
# 14. Mai 2016, 16:00
# Palmeiras
# Athletico Paranaense
# 4 - 0
# minuto do gol: ['87']
# 3 - 0
# minuto do gol: ['87', '52']
# 2 - 0
# minuto do gol: ['87', '52', '46']
# 1 - 0
# minuto do gol: ['87', '52', '46', '19']
# Brasil
# Brasileiro Série A
# 2016
# 14. Mai 2016, 18:30
# Atlético Mineiro
# Santos
# 1 - 0
# minuto do gol: ['15']
# Brasil
# Brasileiro Série A
# 2016
# 14. Mai 2016, 21:00
# Coritiba
# Cruzeiro
# 1 - 0
# minuto do gol: ['71']
# Brasil
# Brasileiro Série A
# 2016
# 15. Mai 2016, 11:00
# Botafogo
# São Paulo
# 1 - 0
# minuto do gol: ['22']
# Brasil
# Brasileiro Série A
# 2016
# 15. Mai 2016, 11:00
# Santa Cruz
# Vitória
# 1 - 0
# minuto do gol: ['80']
# 4 - 1
# minuto do gol: ['80', '87']
# 3 - 1
# minuto do gol: ['80', '87', '85']
# 2 - 0
# minuto do gol: ['80', '87', '85', '44']
# 1 - 0
# ...

# %%
a = []
a.append(1)
a.append(2)
a.append(9)
a.reverse()
print(a)
# Out:
# [9, 2, 1]
