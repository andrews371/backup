# %%
# validação de método - versão baseada nos dados main leagues football data

import csv 
import statistics as st
import math
import numpy as np



def ano_dados(camp,saldo_parcial,saldo_pm,rs,mrs,acumulador,stake):
    # base de dados
    time_casa = ''
    time_fora = ''
    num_jogos = 0
    num_gols = 0
    media_gols = 0

    # para média de gols dos times
    mgf_tcasa = 0
    mgs_tcasa = 0
    mgf_tfora = 0
    mgs_tfora = 0

    # para média de gols do campeonato
    # antes da rodada em questão
    tgf_ccasa_ant = 0
    tgf_cfora_ant = 0
    mgf_ccasa_ant = 0
    mgs_ccasa_ant = 0
    mgf_cfora_ant = 0
    mgs_cfora_ant = 0

    # depois da rodada em questão
    mgf_ccasa = 0
    mgs_ccasa = 0
    mgf_cfora = 0
    mgs_cfora = 0

    time_ant = [''] * 20 # recebe dados do time antes do jogo da rodada
    time = [''] * 20     # recebe dados do time depois de ser realizado o jogo da rodada em quetão

    tgf_ccasa = 0
    tgf_cfora = 0

    cont1 = 0
    cont_jogos = 0
    rodada = 1
    cont_geral = 1
    cont_ind = [0] * 20

    time1_ant = ''
    time2_ant = ''
    time1 = ''
    time2 = ''
    dentro_rodada = 0

    odd_pca = 0
    odd_pea = 0
    odd_pfa = 0

    ojc = 0
    oje = 0
    ojf = 0

    resultado = ''
    num_entradas = 0

    taxa_1x0 = 0
    taxa_n1x0 = 0
    total_ja = 0

    # últimos resultados
    urc = [''] * 20
    urf = [''] * 20
    
    caux = 0
    valor_inv = 0
    
    with open(camp, 'r', encoding = 'utf-8', newline = '') as al:
        arq1 = csv.DictReader(al)
        
        for linha in arq1:
            try: 
                # odd match odds Pinnacle
                odd_pca = float(linha['PSH'])
                odd_pea = float(linha['PSD'])
                odd_pfa = float(linha['PSA']) 

                # resultado do jogo
                resultado = linha['FTR']
                resultadoht = linha['HTR']

                # média de gols do campeonato antes da rodada em questão
                tgf_ccasa_ant = tgf_ccasa
                tgf_cfora_ant = tgf_cfora
                mgf_ccasa_ant = mgf_ccasa
                mgs_ccasa_ant = mgs_ccasa
                mgf_cfora_ant = mgf_cfora
                mgs_cfora_ant = mgs_cfora

                # média de gols do campeonato depois da rodada em questão
                tgf_ccasa += float(linha['FTHG'])
                tgf_cfora += float(linha['FTAG'])
                mgf_ccasa = tgf_ccasa/cont_geral
                mgs_ccasa = tgf_cfora/cont_geral
                mgf_cfora = mgs_ccasa
                mgs_cfora = mgf_ccasa

                # carregando os times e o número de jogos de cada
                if cont1 < 10:
                    cont_ind[cont1] += 1
                    cont_ind[cont1+10] += 1
                    urc[cont1] = linha['HomeTeam']
                    urc[cont1+10] = linha['AwayTeam']
                    urf[cont1] = linha['HomeTeam']
                    urf[cont1+10] = linha['AwayTeam']

                    time[cont1] = {'time':linha['HomeTeam'],'num_jogosc':cont_ind[cont1],'num_jogosf':0,'tgf_tcasa':int(linha['FTHG']),'tgs_tcasa':int(linha['FTAG']),'tgf_tfora':0,'tgs_tfora':0,'mgf_tcasa':float(linha['FTHG'])/cont_ind[cont1],'mgs_tcasa':float(linha['FTAG'])/cont_ind[cont1],'mgf_tfora':0,'mgs_tfora':0}
                    time[cont1+10] = {'time':linha['AwayTeam'],'num_jogosc':0,'num_jogosf':cont_ind[cont1+10],'tgf_tcasa':0,'tgs_tcasa':0,'tgf_tfora':int(linha['FTAG']),'tgs_tfora':int(linha['FTHG']),'mgf_tcasa':0,'mgs_tcasa':0,'mgf_tfora':float(linha['FTAG'])/cont_ind[cont1+10],'mgs_tfora':float(linha['FTHG'])/cont_ind[cont1+10]}
                    cont1 += 1                  

                # contando jogos
                if cont_jogos <= 10:
                    cont_jogos += 1

                # atualizando os dados dos times por jogo
                if cont_geral >= 10:     
                    for i in range(20):
                        if linha['HomeTeam'] == time[i]['time']: 
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosc'] += 1
                            time[i]['tgf_tcasa'] += int(linha['FTHG'])
                            time[i]['tgs_tcasa'] += int(linha['FTAG'])

                            time[i]['mgf_tcasa'] = time[i]['tgf_tcasa']/time[i]['num_jogosc']
                            time[i]['mgs_tcasa'] = time[i]['tgs_tcasa']/time[i]['num_jogosc']

                        if linha['AwayTeam'] == time[i]['time']:
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosf'] += 1
                            time[i]['tgf_tfora'] += int(linha['FTAG'])
                            time[i]['tgs_tfora'] += int(linha['FTHG'])

                            time[i]['mgf_tfora'] = time[i]['tgf_tfora']/time[i]['num_jogosf']
                            time[i]['mgs_tfora'] = time[i]['tgs_tfora']/time[i]['num_jogosf']


                #contando rodadas - a primeira vez que entra aqui é a rodada 2
                if cont_jogos > 10 or dentro_rodada < 10:
                    # atualizando o número de rodadas
                    if cont_jogos > 10:
                        rodada += 1
                        cont_jogos = 1
                        dentro_rodada = 0



                    dentro_rodada += 1

                    #carregando times com dados da rodada para chamar o método
                    if rodada > 1:
                        for i in range(20):                 
                            if linha['HomeTeam'] == time[i]['time']:
                                time1_ant = time_ant[i] # time1 antes da rodada em questão
                                time1 = time[i]         # time1 depois da rodada em questão
                            if linha['AwayTeam'] == time[i]['time']:
                                time2_ant = time_ant[i] # time2 antes da rodada em questão
                                time2 = time[i]         # time2 depois da rodada em questão


                    #print('número de jogos: {}'.format(cont_geral))
                    # chamando o método para cálculo de probabilidades
                    
                    if rodada > 0:
                        if odd_pca >= 1.9 and odd_pca <= 3 and int(linha['HST']) <= (int(linha['AST']) + 2) :
                            #acumulador += 1
                            
                            # para juros compostos
                            if (0.01083 * saldo_parcial) <= 2000:
                                stake2 = 0.01083 * saldo_parcial
                            else:
                                stake2 = 2000
                                #print(f'partidas jogadas até stake de 2000 {acumulador}')                                
                            
                            # para usar stake fixa basta descomentar a linha abaixo
                            #stake2 = stake
                            
                            # Análise de banca quebrada
                            if saldo_parcial < stake2:
                                print('VOCÊ QUEBROU A BANCA')
                            
                            if resultado == 'H' and int(linha['FTHG']) >= 4 :
                                taxa_1x0 += 1
                                saldo_parcial -= stake2 * 24
                                rs += 1
                                print(f'Red {saldo_parcial:.2f}')
                                
                            else:
                                taxa_n1x0 += 1
                                saldo_parcial += stake2 
                                rs = 0
                                print(f'Green {saldo_parcial:.2f}')
                           
                            # verificação de reds seguidos
                            if rs > mrs:
                                mrs = rs
                            
                            # verificação de saldo mínimo
                            if saldo_parcial < saldo_pm:
                                saldo_pm = saldo_parcial
                            
                            # Para cálculo de ROI    
                            valor_inv += stake2  
                            
                            # Total de entradas feitas
                            total_ja += 1
                        
                            
                        elif odd_pfa >= 1.9 and odd_pfa <= 3 and int(linha['AST']) <= (int(linha['HST']) + 2) :
                            #acumulador += 1
                            
                            # para juros compostos    
                            if (0.01083 * saldo_parcial) <= 2000:
                                stake2 = 0.01083 * saldo_parcial
                            else:
                                stake2 = 2000
                                #print(f'partidas jogadas até stake de 2000 {acumulador}')                                
                            
                            # para usar stake fixa basta descomentar a linha abaixo
                            #stake2 = stake
                            
                            # Análise de banca quebrada
                            if saldo_parcial < stake2:
                                print('VOCÊ QUEBROU A BANCA')
                            
                            if resultado == 'A' and int(linha['FTAG']) >= 4 :
                                taxa_1x0 += 1
                                saldo_parcial -= stake2 * 24
                                rs += 1
                                print(f'Red {saldo_parcial:.2f}')
                                
                            else:
                                taxa_n1x0 += 1
                                saldo_parcial += stake2 
                                rs = 0 
                                print(f'Green {saldo_parcial:.2f}')
                            
                            # verificação de reds seguidos
                            if rs > mrs:
                                mrs = rs
                            
                            # verificação de saldo mínimo
                            if saldo_parcial < saldo_pm:
                                saldo_pm = saldo_parcial
                            
                            # Para cálculo de ROI    
                            valor_inv += stake2  
                            
                            # Total de entradas feitas
                            total_ja += 1 
                        
                cont_geral += 1
            except:
                continue
                
    return saldo_parcial,saldo_pm,cont_geral-1,taxa_n1x0,taxa_1x0,total_ja,rs,mrs,valor_inv,acumulador
        
    
# programa principal
# ano a ser avaliado
ent2 = input('Campeonato: ')

# para fazer cálculo de lucro ou perda por mês depois
meses = 0 

tam_ent2 = len(ent2.split(','))
ent2 = ent2.split(',')

for i in range(tam_ent2): 
    if i == 0:
        if ent2[i].lower() == 's': # aqui poderia ser upper() no lugar de lower() mas a letra depois de "==" teria que ser maiúscula
            entrada2 = 's1,s2,s3,s4,s5,s6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'p':
            entrada2 = 'p1,p2,p3,p4,p5,p6,p7,p8,p9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'e':
            entrada2 = 'e1,e2,e3,e4,e5,e6,e7'.upper().split(',')
            meses = 84
        elif ent2[i].lower() == 'ec':
            entrada2 = 'ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8'.upper().split(',')
            meses = 96
        elif ent2[i].lower() == 't':
            entrada2 = 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'b':
            entrada2 = 'b1,b2,b3,b4,b5,b6,b7,b8,b9,b10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'f':
            entrada2 = 'f1,f2,f3,f4,f5,f6,f7,f8,f9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'g':
            entrada2 = 'g1,g2,g3,g4,g5,g6,g7,g8,g9,g10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'i':
            entrada2 = 'i1,i2,i3,i4,i5,i6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'd':
            entrada2 = 'd1,d2,d3,d4,d5,d6,d7,d8,d9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'n':
            entrada2 = 'n1,n2,n3,n4,n5,n6,n7,n8,n9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'sc':
            entrada2 = 'sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')
            meses = 108
        elif ent2[i] == '1':
            entrada2 = 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1'.upper().split(',')
            meses = 12
        elif ent2[i] == '2':
            entrada2 = 's2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2'.upper().split(',')
            meses = 12
        elif ent2[i] == '3':
            entrada2 = 's3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3'.upper().split(',')
            meses = 12
        elif ent2[i] == '4':
            entrada2 = 's4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4'.upper().split(',')
            meses = 12
        elif ent2[i] == '5':
            entrada2 = 's5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5'.upper().split(',')
            meses = 12
        elif ent2[i] == '6':
            entrada2 = 's6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')
            meses = 12
        elif ent2[i].lower() == '6 anos':
            entrada2 = 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1,s2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2,s3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3,s4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4,s5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5,s6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')    
            meses = 72
        elif ent2[i].lower() == 'todos':
            entrada2 = 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10,b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,e1,e2,e3,e4,e5,e6,e7,ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8,ec9,f1,f2,f3,f4,f5,f6,f7,f8,f9,g,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,i1,i2,i3,i4,i5,i6,n1,n2,n3,n4,n5,n6,n7,n8,n9,p1,p2,p3,p4,p5,p6,p7,p8,p9,s1,s2,s3,s4,s5,s6,sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')  
            meses = 'NULL'
        else:
            try:
                int(ent2[i])
                entrada2 = ent2.upper().split(',') # campeonato -> entrada2
                meses = tam_ent2 * 12
            except:
                continue
    else:
        if ent2[i].lower() == 's': # aqui poderia ser upper() no lugar de lower() mas a letra depois de "==" teria que ser maiúscula
            entrada2 += 's1,s2,s3,s4,s5,s6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'p':
            entrada2 += 'p1,p2,p3,p4,p5,p6,p7,p8,p9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'e':
            entrada2 += 'e1,e2,e3,e4,e5,e6,e7'.upper().split(',')
            meses = 84
        elif ent2[i].lower() == 'ec':
            entrada2 += 'ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8'.upper().split(',')
            meses = 96
        elif ent2[i].lower() == 't':
            entrada2 += 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'b':
            entrada2 += 'b1,b2,b3,b4,b5,b6,b7,b8,b9,b10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'f':
            entrada2 += 'f1,f2,f3,f4,f5,f6,f7,f8,f9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'g':
            entrada2 += 'g1,g2,g3,g4,g5,g6,g7,g8,g9,g10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'i':
            entrada2 += 'i1,i2,i3,i4,i5,i6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'd':
            entrada2 += 'd1,d2,d3,d4,d5,d6,d7,d8,d9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'n':
            entrada2 += 'n1,n2,n3,n4,n5,n6,n7,n8,n9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'sc':
            entrada2 += 'sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')
            meses = 108
        elif ent2[i] == '1':
            entrada2 += 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1'.upper().split(',')
            meses += 12
        elif ent2[i] == '2':
            entrada2 += 's2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2'.upper().split(',')
            meses += 12
        elif ent2[i] == '3':
            entrada2 += 's3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3'.upper().split(',')
            meses += 12
        elif ent2[i] == '4':
            entrada2 += 's4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4'.upper().split(',')
            meses += 12
        elif ent2[i] == '5':
            entrada2 += 's5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5'.upper().split(',')
            meses += 12
        elif ent2[i] == '6':
            entrada2 += 's6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')
            meses += 12
        else:
            try:
                int(ent2[i])
                entrada2 = ent2.upper().split(',') # campeonato -> entrada2
                meses = tam_ent2 * 12
            except:
                continue
        
tam_entrada2 = len(entrada2)

print('\n')

for i in range(tam_entrada2):
    entrada2[i] +='.csv'

acumulador = 0
taxa_n1x0 = 0
taxa_1x0 = 0
total_ja = 0
num_jogos = 0
rs = 0
mrs = 0
fmrs = 0
caux = 0
saldo_pm = 100000 # valor fixo que tem que ser maior que a banca

fvalor_inv = 0
valor_inv = 0
fcaux = 0
frs = 0
valor_inicial = 9
stake = valor_inicial * 0.2
stake = 3
perc_banca = 0
roi = 0
saldo_final = valor_inicial
saldo_parcial = saldo_final
fnum_jogos = 0
ftaxa_n1x0 = 0
ftaxa_1x0 = 0
ftotal_ja = 0

ftaxa_al = []
ftaxa_ab = []

for i in range(tam_entrada2):
    try:
        saldo_parcial,saldo_pm,num_jogos,taxa_n1x0,taxa_1x0,total_ja,rs,mrs,valor_inv,acumulador = ano_dados(entrada2[i],saldo_parcial,saldo_pm,rs,mrs,acumulador,stake)
        fcaux += caux
        saldo_final += saldo_parcial
        fnum_jogos += num_jogos
        ftaxa_n1x0 += taxa_n1x0
        ftaxa_1x0 += taxa_1x0
        ftotal_ja += total_ja
        ftaxa_al.append((ftaxa_n1x0*100) / ftotal_ja)
        ftaxa_ab.append((ftaxa_1x0*100) / ftotal_ja)
        fvalor_inv += valor_inv
        
        #print('Banca parcial {s:.2f}\n'.format(s = saldo_final))
    except:
        continue
        

if ftotal_ja == 0:
    print('Nenhum jogo encontrado')
    
else:
    d_odd_lay = (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))             
    
    if d_odd_lay == 0:
        print(f'Total de jogos analisados: {ftotal_ja}')
        print('Nenhum deles foi 1x0\n')
    else:
        saldo_final = saldo_parcial
        odd_lay = 100 / (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))
        odd_back = 100 / ((ftaxa_1x0 * 100) / (ftotal_ja)) 
        so_odd_lay = 100 / (100 - st.median(ftaxa_al))
        so_odd_back = 100 / st.median(ftaxa_ab)

        # Cálculo da média de lucros e ROI mensal
        if ent2[0].lower() != 'todos':
            perc_banca = (((saldo_final - valor_inicial) / meses) * 100) / valor_inicial
            roi = (((saldo_final - valor_inicial) / meses) * 100) / ((fvalor_inv) / meses)
            
        print(f'\nTotal de jogos: {fnum_jogos}')
        print(f'Total de jogos analisados: {ftotal_ja}\n')
        
        print(f'Máximo de reds seguidos {mrs}')
        print(f'Saldo mínimo na temporada {saldo_pm:.2f}')
        print('taxa de 1x0: {} -> {t:.2f}%'.format(ftaxa_1x0,t = (ftaxa_1x0*100) / ftotal_ja))
        print(f'taxa de 1x0 (tirando outliers): {st.median(ftaxa_ab):.2f}%')
        print(f'Odd back ideal ACIMA de: {odd_back:.2f}')
        print(f'Odd back ideal (tirando outliers) ACIMA de: {so_odd_back:.2f}\n')

        print('taxa de nao 1x0: {} -> {tn:.2f}%'.format(ftaxa_n1x0,tn = (ftaxa_n1x0*100) / ftotal_ja))
        print(f'taxa de não 1x0 (tirando outliers): {st.median(ftaxa_al):.2f}%')
        print(f'Odd lay ideal ABAIXO de: {odd_lay:.2f}')
        print(f'Odd lay ideal (tirando outliers) ABAIXO de: {so_odd_lay:.2f}\n')
# Green 5463839.20
# Green 5465839.20
# Green 5467839.20
# Green 5469839.20
# Green 5471839.20
# Green 5473839.20
# Red 5425839.20
# Green 5427839.20
# Green 5429839.20
# Green 5431839.20
# Green 5433839.20
# Green 5435839.20
# Green 5437839.20
# Green 5439839.20
# Green 5441839.20
# Green 5443839.20
# Green 5445839.20
# Green 5447839.20
# Green 5449839.20
# Green 5451839.20
# Green 5453839.20
# Green 5455839.20
# Green 5457839.20
# Green 5459839.20
# Green 5461839.20
# Red 5413839.20
# Green 5415839.20
# Green 5417839.20
# Green 5419839.20
# Green 5421839.20
# Green 5423839.20
# Green 5425839.20
# Green 5427839.20
# Green 5429839.20
# Green 5431839.20
# Green 5433839.20
# Green 5435839.20
# Green 5437839.20
# Green 5439839.20
# Green 5441839.20
# Green 5443839.20
# Green 5445839.20
# Green 5447839.20
# Green 5449839.20
# Green 5451839.20
# Green 5453839.20
# Green 5455839.20
# Green 5457839.20
# Green 5459839.20
# Green 5461839.20
# Green 5463839.20
# Green 5465839.20
# Green 5467839.20
# Green 5469839.20
# Green 5471839.20
# Green 5473839.20
# Green 5475839.20
# Green 5477839.20
# Green 5479839.20
# Green 5481839.20
# Green 5483839.20
# Green 5485839.20
# Green 5487839.20
# Green 5489839.20
#
# Total de jogos: 20268
# Total de jogos analisados: 7907
#
# Máximo de reds seguidos 2
# Saldo mínimo na temporada 7.50
# taxa de 1x0: 164 -> 2.07%
# taxa de 1x0 (tirando outliers): 2.13%
# Odd back ideal ACIMA de: 48.21
# Odd back ideal (tirando outliers) ACIMA de: 46.94
#
# taxa de nao 1x0: 7743 -> 97.93%
# taxa de não 1x0 (tirando outliers): 97.87%
# Odd lay ideal ABAIXO de: 48.21
# Odd lay ideal (tirando outliers) ABAIXO de: 46.94
#
# Banca inicial 9.00
# Stake usada 3
# Saldo final 5489839.20
# Lucro médio mensal 76247.64
# Percentual de lucro médio mensal sobre a banca 847196.02%
# Roi médio mensal 50.76%

# %%
# validação de método - versão baseada nos dados main leagues football data

import csv 
import statistics as st
import math
import numpy as np



def ano_dados(camp,saldo_parcial,saldo_pm,rs,mrs,acumulador,stake):
    # base de dados
    time_casa = ''
    time_fora = ''
    num_jogos = 0
    num_gols = 0
    media_gols = 0

    # para média de gols dos times
    mgf_tcasa = 0
    mgs_tcasa = 0
    mgf_tfora = 0
    mgs_tfora = 0

    # para média de gols do campeonato
    # antes da rodada em questão
    tgf_ccasa_ant = 0
    tgf_cfora_ant = 0
    mgf_ccasa_ant = 0
    mgs_ccasa_ant = 0
    mgf_cfora_ant = 0
    mgs_cfora_ant = 0

    # depois da rodada em questão
    mgf_ccasa = 0
    mgs_ccasa = 0
    mgf_cfora = 0
    mgs_cfora = 0

    time_ant = [''] * 20 # recebe dados do time antes do jogo da rodada
    time = [''] * 20     # recebe dados do time depois de ser realizado o jogo da rodada em quetão

    tgf_ccasa = 0
    tgf_cfora = 0

    cont1 = 0
    cont_jogos = 0
    rodada = 1
    cont_geral = 1
    cont_ind = [0] * 20

    time1_ant = ''
    time2_ant = ''
    time1 = ''
    time2 = ''
    dentro_rodada = 0

    odd_pca = 0
    odd_pea = 0
    odd_pfa = 0

    ojc = 0
    oje = 0
    ojf = 0

    resultado = ''
    num_entradas = 0

    taxa_1x0 = 0
    taxa_n1x0 = 0
    total_ja = 0

    # últimos resultados
    urc = [''] * 20
    urf = [''] * 20
    
    caux = 0
    valor_inv = 0
    
    with open(camp, 'r', encoding = 'utf-8', newline = '') as al:
        arq1 = csv.DictReader(al)
        
        for linha in arq1:
            try: 
                # odd match odds Pinnacle
                odd_pca = float(linha['PSH'])
                odd_pea = float(linha['PSD'])
                odd_pfa = float(linha['PSA']) 

                # resultado do jogo
                resultado = linha['FTR']
                resultadoht = linha['HTR']

                # média de gols do campeonato antes da rodada em questão
                tgf_ccasa_ant = tgf_ccasa
                tgf_cfora_ant = tgf_cfora
                mgf_ccasa_ant = mgf_ccasa
                mgs_ccasa_ant = mgs_ccasa
                mgf_cfora_ant = mgf_cfora
                mgs_cfora_ant = mgs_cfora

                # média de gols do campeonato depois da rodada em questão
                tgf_ccasa += float(linha['FTHG'])
                tgf_cfora += float(linha['FTAG'])
                mgf_ccasa = tgf_ccasa/cont_geral
                mgs_ccasa = tgf_cfora/cont_geral
                mgf_cfora = mgs_ccasa
                mgs_cfora = mgf_ccasa

                # carregando os times e o número de jogos de cada
                if cont1 < 10:
                    cont_ind[cont1] += 1
                    cont_ind[cont1+10] += 1
                    urc[cont1] = linha['HomeTeam']
                    urc[cont1+10] = linha['AwayTeam']
                    urf[cont1] = linha['HomeTeam']
                    urf[cont1+10] = linha['AwayTeam']

                    time[cont1] = {'time':linha['HomeTeam'],'num_jogosc':cont_ind[cont1],'num_jogosf':0,'tgf_tcasa':int(linha['FTHG']),'tgs_tcasa':int(linha['FTAG']),'tgf_tfora':0,'tgs_tfora':0,'mgf_tcasa':float(linha['FTHG'])/cont_ind[cont1],'mgs_tcasa':float(linha['FTAG'])/cont_ind[cont1],'mgf_tfora':0,'mgs_tfora':0}
                    time[cont1+10] = {'time':linha['AwayTeam'],'num_jogosc':0,'num_jogosf':cont_ind[cont1+10],'tgf_tcasa':0,'tgs_tcasa':0,'tgf_tfora':int(linha['FTAG']),'tgs_tfora':int(linha['FTHG']),'mgf_tcasa':0,'mgs_tcasa':0,'mgf_tfora':float(linha['FTAG'])/cont_ind[cont1+10],'mgs_tfora':float(linha['FTHG'])/cont_ind[cont1+10]}
                    cont1 += 1                  

                # contando jogos
                if cont_jogos <= 10:
                    cont_jogos += 1

                # atualizando os dados dos times por jogo
                if cont_geral >= 10:     
                    for i in range(20):
                        if linha['HomeTeam'] == time[i]['time']: 
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosc'] += 1
                            time[i]['tgf_tcasa'] += int(linha['FTHG'])
                            time[i]['tgs_tcasa'] += int(linha['FTAG'])

                            time[i]['mgf_tcasa'] = time[i]['tgf_tcasa']/time[i]['num_jogosc']
                            time[i]['mgs_tcasa'] = time[i]['tgs_tcasa']/time[i]['num_jogosc']

                        if linha['AwayTeam'] == time[i]['time']:
                            time_ant[i] = time[i].copy() # time antes da rodada em questão

                            # atualização dos times após os jogos da rodada
                            time[i]['num_jogosf'] += 1
                            time[i]['tgf_tfora'] += int(linha['FTAG'])
                            time[i]['tgs_tfora'] += int(linha['FTHG'])

                            time[i]['mgf_tfora'] = time[i]['tgf_tfora']/time[i]['num_jogosf']
                            time[i]['mgs_tfora'] = time[i]['tgs_tfora']/time[i]['num_jogosf']


                #contando rodadas - a primeira vez que entra aqui é a rodada 2
                if cont_jogos > 10 or dentro_rodada < 10:
                    # atualizando o número de rodadas
                    if cont_jogos > 10:
                        rodada += 1
                        cont_jogos = 1
                        dentro_rodada = 0



                    dentro_rodada += 1

                    #carregando times com dados da rodada para chamar o método
                    if rodada > 1:
                        for i in range(20):                 
                            if linha['HomeTeam'] == time[i]['time']:
                                time1_ant = time_ant[i] # time1 antes da rodada em questão
                                time1 = time[i]         # time1 depois da rodada em questão
                            if linha['AwayTeam'] == time[i]['time']:
                                time2_ant = time_ant[i] # time2 antes da rodada em questão
                                time2 = time[i]         # time2 depois da rodada em questão


                    #print('número de jogos: {}'.format(cont_geral))
                    # chamando o método para cálculo de probabilidades
                    
                    if rodada > 0:
                        if odd_pca >= 1.9 and int(linha['HST']) > int(linha['AST']) and int(linha['HTHG']) == 1 and int(linha['HTAG']) == 0 :
                            #acumulador += 1
                            
                            # para juros compostos
                            if (0.05 * saldo_parcial) <= 2000:
                                stake2 = 0.05 * saldo_parcial
                            else:
                                stake2 = 2000
                                #print(f'partidas jogadas até stake de 2000 {acumulador}')                                

                            # para usar stake fixa basta descomentar a linha abaixo
                            stake2 = stake

                            # Análise de banca quebrada
                            if saldo_parcial < stake2:
                                print('VOCÊ QUEBROU A BANCA')

                            if resultado == 'H' :
                                taxa_1x0 += 1
                                saldo_parcial += stake2 * 0.4
                                rs = 0
                                #print(f'Green {saldo_parcial:.2f}')

                            else:
                                taxa_n1x0 += 1
                                saldo_parcial -= stake2 
                                rs += 1
                                #print(f'Red {saldo_parcial:.2f}')

                            # verificação de reds seguidos
                            if rs > mrs:
                                mrs = rs

                            # verificação de saldo mínimo
                            if saldo_parcial < saldo_pm:
                                saldo_pm = saldo_parcial

                            # Para cálculo de ROI    
                            valor_inv += stake2  

                            # Total de entradas feitas
                            total_ja += 1

                            
                        elif odd_pfa >= 1.9 and int(linha['AST']) > int(linha['HST']) and int(linha['HTHG']) == 0 and int(linha['HTAG']) == 1 :
                            #acumulador += 1

                            # para juros compostos    
                            if (0.05 * saldo_parcial) <= 2000:
                                stake2 = 0.05 * saldo_parcial
                            else:
                                stake2 = 2000
                                #print(f'partidas jogadas até stake de 2000 {acumulador}')                                

                            # para usar stake fixa basta descomentar a linha abaixo
                            stake2 = stake

                            # Análise de banca quebrada
                            if saldo_parcial < stake2:
                                print('VOCÊ QUEBROU A BANCA')

                            if resultado == 'A' :
                                taxa_1x0 += 1
                                saldo_parcial += stake2 * 0.4
                                rs = 0
                                #print(f'Green {saldo_parcial:.2f}')

                            else:
                                taxa_n1x0 += 1
                                saldo_parcial -= stake2 
                                rs += 1 
                                #print(f'Red {saldo_parcial:.2f}')

                            # verificação de reds seguidos
                            if rs > mrs:
                                mrs = rs

                            # verificação de saldo mínimo
                            if saldo_parcial < saldo_pm:
                                saldo_pm = saldo_parcial

                            # Para cálculo de ROI    
                            valor_inv += stake2  

                            # Total de entradas feitas
                            total_ja += 1 

                cont_geral += 1
            except:
                continue
                
    return saldo_parcial,saldo_pm,cont_geral-1,taxa_n1x0,taxa_1x0,total_ja,rs,mrs,valor_inv,acumulador
        
    
# programa principal
# ano a ser avaliado
ent2 = input('Campeonato: ')

# para fazer cálculo de lucro ou perda por mês depois
meses = 0 

tam_ent2 = len(ent2.split(','))
ent2 = ent2.split(',')

for i in range(tam_ent2): 
    if i == 0:
        if ent2[i].lower() == 's': # aqui poderia ser upper() no lugar de lower() mas a letra depois de "==" teria que ser maiúscula
            entrada2 = 's1,s2,s3,s4,s5,s6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'p':
            entrada2 = 'p1,p2,p3,p4,p5,p6,p7,p8,p9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'e':
            entrada2 = 'e1,e2,e3,e4,e5,e6,e7'.upper().split(',')
            meses = 84
        elif ent2[i].lower() == 'ec':
            entrada2 = 'ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8'.upper().split(',')
            meses = 96
        elif ent2[i].lower() == 't':
            entrada2 = 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'b':
            entrada2 = 'b1,b2,b3,b4,b5,b6,b7,b8,b9,b10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'f':
            entrada2 = 'f1,f2,f3,f4,f5,f6,f7,f8,f9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'g':
            entrada2 = 'g1,g2,g3,g4,g5,g6,g7,g8,g9,g10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'i':
            entrada2 = 'i1,i2,i3,i4,i5,i6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'd':
            entrada2 = 'd1,d2,d3,d4,d5,d6,d7,d8,d9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'n':
            entrada2 = 'n1,n2,n3,n4,n5,n6,n7,n8,n9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'sc':
            entrada2 = 'sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')
            meses = 108
        elif ent2[i] == '1':
            entrada2 = 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1'.upper().split(',')
            meses = 12
        elif ent2[i] == '2':
            entrada2 = 's2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2'.upper().split(',')
            meses = 12
        elif ent2[i] == '3':
            entrada2 = 's3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3'.upper().split(',')
            meses = 12
        elif ent2[i] == '4':
            entrada2 = 's4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4'.upper().split(',')
            meses = 12
        elif ent2[i] == '5':
            entrada2 = 's5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5'.upper().split(',')
            meses = 12
        elif ent2[i] == '6':
            entrada2 = 's6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')
            meses = 12
        elif ent2[i].lower() == '6 anos':
            entrada2 = 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1,s2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2,s3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3,s4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4,s5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5,s6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')    
            meses = 72
        elif ent2[i].lower() == 'todos':
            entrada2 = 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10,b1,b2,b3,b4,b5,b6,b7,b8,b9,b10,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,e1,e2,e3,e4,e5,e6,e7,ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8,ec9,f1,f2,f3,f4,f5,f6,f7,f8,f9,g,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,i1,i2,i3,i4,i5,i6,n1,n2,n3,n4,n5,n6,n7,n8,n9,p1,p2,p3,p4,p5,p6,p7,p8,p9,s1,s2,s3,s4,s5,s6,sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')  
            meses = 'NULL'
        else:
            try:
                int(ent2[i])
                entrada2 = ent2.upper().split(',') # campeonato -> entrada2
                meses = tam_ent2 * 12
            except:
                continue
    else:
        if ent2[i].lower() == 's': # aqui poderia ser upper() no lugar de lower() mas a letra depois de "==" teria que ser maiúscula
            entrada2 += 's1,s2,s3,s4,s5,s6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'p':
            entrada2 += 'p1,p2,p3,p4,p5,p6,p7,p8,p9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'e':
            entrada2 += 'e1,e2,e3,e4,e5,e6,e7'.upper().split(',')
            meses = 84
        elif ent2[i].lower() == 'ec':
            entrada2 += 'ec1,ec2,ec3,ec4,ec5,ec6,ec7,ec8'.upper().split(',')
            meses = 96
        elif ent2[i].lower() == 't':
            entrada2 += 't1,t2,t3,t4,t5,t6,t7,t8,t9,t10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'b':
            entrada2 += 'b1,b2,b3,b4,b5,b6,b7,b8,b9,b10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'f':
            entrada2 += 'f1,f2,f3,f4,f5,f6,f7,f8,f9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'g':
            entrada2 += 'g1,g2,g3,g4,g5,g6,g7,g8,g9,g10'.upper().split(',')
            meses = 120
        elif ent2[i].lower() == 'i':
            entrada2 += 'i1,i2,i3,i4,i5,i6'.upper().split(',')
            meses = 72
        elif ent2[i].lower() == 'd':
            entrada2 += 'd1,d2,d3,d4,d5,d6,d7,d8,d9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'n':
            entrada2 += 'n1,n2,n3,n4,n5,n6,n7,n8,n9'.upper().split(',')
            meses = 108
        elif ent2[i].lower() == 'sc':
            entrada2 += 'sc1,sc2,sc3,sc4,sc5,sc6,sc7,sc8,sc9'.upper().split(',')
            meses = 108
        elif ent2[i] == '1':
            entrada2 += 's1,p1,e1,t1,b1,f1,g1,i1,ec1,d1,n1,sc1'.upper().split(',')
            meses += 12
        elif ent2[i] == '2':
            entrada2 += 's2,p2,e2,t2,b2,f2,g2,i2,ec2,d2,n2,sc2'.upper().split(',')
            meses += 12
        elif ent2[i] == '3':
            entrada2 += 's3,p3,e3,t3,b3,f3,g3,i3,ec3,d3,n3,sc3'.upper().split(',')
            meses += 12
        elif ent2[i] == '4':
            entrada2 += 's4,p4,e4,t4,b4,f4,g4,i4,ec4,d4,n4,sc4'.upper().split(',')
            meses += 12
        elif ent2[i] == '5':
            entrada2 += 's5,p5,e5,t5,b5,f5,g5,i5,ec5,d5,n5,sc5'.upper().split(',')
            meses += 12
        elif ent2[i] == '6':
            entrada2 += 's6,p6,e6,t6,b6,f6,g6,i6,ec6,d6,n6,sc6'.upper().split(',')
            meses += 12
        else:
            try:
                int(ent2[i])
                entrada2 = ent2.upper().split(',') # campeonato -> entrada2
                meses = tam_ent2 * 12
            except:
                continue
        
tam_entrada2 = len(entrada2)

print('\n')

for i in range(tam_entrada2):
    entrada2[i] +='.csv'

acumulador = 0
taxa_n1x0 = 0
taxa_1x0 = 0
total_ja = 0
num_jogos = 0
rs = 0
mrs = 0
fmrs = 0
caux = 0
saldo_pm = 100000 # valor fixo que tem que ser maior que a banca

fvalor_inv = 0
valor_inv = 0
fcaux = 0
frs = 0
valor_inicial = 100
stake = valor_inicial * 0.05
#stake = 3
perc_banca = 0
roi = 0
saldo_final = valor_inicial
saldo_parcial = saldo_final
fnum_jogos = 0
ftaxa_n1x0 = 0
ftaxa_1x0 = 0
ftotal_ja = 0

ftaxa_al = []
ftaxa_ab = []

for i in range(tam_entrada2):
    try:
        saldo_parcial,saldo_pm,num_jogos,taxa_n1x0,taxa_1x0,total_ja,rs,mrs,valor_inv,acumulador = ano_dados(entrada2[i],saldo_parcial,saldo_pm,rs,mrs,acumulador,stake)
        fcaux += caux
        saldo_final += saldo_parcial
        fnum_jogos += num_jogos
        ftaxa_n1x0 += taxa_n1x0
        ftaxa_1x0 += taxa_1x0
        ftotal_ja += total_ja
        ftaxa_al.append((ftaxa_n1x0*100) / ftotal_ja)
        ftaxa_ab.append((ftaxa_1x0*100) / ftotal_ja)
        fvalor_inv += valor_inv
        
        #print('Banca parcial {s:.2f}\n'.format(s = saldo_final))
    except:
        continue
        

if ftotal_ja == 0:
    print('Nenhum jogo encontrado')
    
else:
    d_odd_lay = (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))             
    
    if d_odd_lay == 0:
        print(f'Total de jogos analisados: {ftotal_ja}')
        print('Nenhum deles foi 1x0\n')
    else:
        saldo_final = saldo_parcial
        odd_lay = 100 / (100 - ((ftaxa_n1x0 * 100) / (ftotal_ja)))
        odd_back = 100 / ((ftaxa_1x0 * 100) / (ftotal_ja)) 
        so_odd_lay = 100 / (100 - st.median(ftaxa_al))
        so_odd_back = 100 / st.median(ftaxa_ab)

        # Cálculo da média de lucros e ROI mensal
        if ent2[0].lower() != 'todos':
            perc_banca = (((saldo_final - valor_inicial) / meses) * 100) / valor_inicial
            roi = (((saldo_final - valor_inicial) / meses) * 100) / ((fvalor_inv) / meses)
            
        print(f'\nTotal de jogos: {fnum_jogos}')
        print(f'Total de jogos analisados: {ftotal_ja}\n')
        
        print(f'Máximo de reds seguidos {mrs}')
        print(f'Saldo mínimo na temporada {saldo_pm:.2f}')
        print('taxa de 1x0: {} -> {t:.2f}%'.format(ftaxa_1x0,t = (ftaxa_1x0*100) / ftotal_ja))
        print(f'taxa de 1x0 (tirando outliers): {st.median(ftaxa_ab):.2f}%')
        print(f'Odd back ideal ACIMA de: {odd_back:.2f}')
        print(f'Odd back ideal (tirando outliers) ACIMA de: {so_odd_back:.2f}\n')

        print('taxa de nao 1x0: {} -> {tn:.2f}%'.format(ftaxa_n1x0,tn = (ftaxa_n1x0*100) / ftotal_ja))
        print(f'taxa de não 1x0 (tirando outliers): {st.median(ftaxa_al):.2f}%')
        print(f'Odd lay ideal ABAIXO de: {odd_lay:.2f}')
        print(f'Odd lay ideal (tirando outliers) ABAIXO de: {so_odd_lay:.2f}\n')
        print(f'Banca inicial {valor_inicial:.2f}')
        print(f'Stake usada {stake}')
        print(f'Saldo final {saldo_final:.2f}')
        
        if meses != 'NULL':
            print(f'Lucro médio mensal {((saldo_final - valor_inicial) / meses):.2f}')
        
        if ent2[0].lower() != 'todos':
            print(f'Percentual de lucro médio mensal sobre a banca {perc_banca:.2f}%')
            print(f'Roi médio mensal {roi:.2f}%')
# Out:
# Campeonato: 6 anos
#
#
#
# Total de jogos: 17877
# Total de jogos analisados: 2179
#
# Máximo de reds seguidos 6
# Saldo mínimo na temporada 88.00
# taxa de 1x0: 1703 -> 78.16%
# taxa de 1x0 (tirando outliers): 78.03%
# Odd back ideal ACIMA de: 1.28
# Odd back ideal (tirando outliers) ACIMA de: 1.28
#
# taxa de nao 1x0: 476 -> 21.84%
# taxa de não 1x0 (tirando outliers): 21.97%
# Odd lay ideal ABAIXO de: 1.28
# Odd lay ideal (tirando outliers) ABAIXO de: 1.28
#
# Banca inicial 100.00
# Stake usada 5.0
# Saldo final 1126.00
# Lucro médio mensal 14.25
# Percentual de lucro médio mensal sobre a banca 14.25%
# Roi médio mensal 9.42%
