# %%
'''

import os
import sys

src = os.path.join(os.path.dirname(os.getcwd()))
sys.path.append(src)

from src import utils

'''
pass

# %%
# método get - recebendo dados da net de forma automática

import requests 

from IPython.display import display

# %%
# O MÉTODO ACIMA É BEM SIMPLES, NÃO CHEGUEI A IMPLEMENTAR MAS SE QUISER VER
# SÓ ABRIR O GMAIL E PESQUISAR POR "ROBÔ WEB" E VER OS LINKS. UM DELES ENSINA A PEGAR DADOS DA WEB
# USANDO O IMPORT REQUESTS E O CÓDIGO ACIMA ALÉM DE MAIS UM POUCO DE CÓDIGO.
# MAS PARA PEGAR DADOS DA WEB ELE TAMBÉM ENSINOU UMA MANEIRA MAIS ROBUSTA QUE ESTÁ EXEMPLIFICADA 
# ABAIXO, USANDO O PACOTE BEAUTIFULSOUP. PREFERI IMPLEMENTAR DESTA ÚLTIMA FORMA.

# %%
# método post - mandando dados pela net de forma automática

import requests
import re

session = requests.Session()

url = 'http://testing-ground.scraping.pro/login?mode=login'
data = {'pwd': '12345', 'usr': 'admin'}

headers = {'User-Agent': ''}
session.get('http://testing-ground.scraping.pro/login')
response = session.post(url, data=data, headers=headers)
re.findall('WELCOME', response.text)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url1 = 'https://pt.wikipedia.org/wiki/Campeonato_Brasileiro_de_Futebol_de_2019_-_S%C3%A9rie_A'
resposta = requests.get(url1)

soup = BeautifulSoup(resposta.text, 'html.parser')
tabela = soup.find_all('table')
print(len(tabela))
print(tabela[0])
print(tabela[21])
# Out:
# 23
# <table class="noprint" style="width:80%; margin:0 auto; margin-bottom:5px; border-collapse:collapse; background: #fbfbfb; border: 1px solid #aaa; border-left: 10px solid #1e90ff;">
# <tbody><tr>
# <td style="width: 8%; text-align: center;"><div style="width:52px; padding-top:5px"> <a class="image" href="/wiki/Ficheiro:Gnome_globe_current_event.svg"><img alt="Gnome globe current event.svg" data-file-height="600" data-file-width="600" decoding="async" height="40" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Gnome_globe_current_event.svg/40px-Gnome_globe_current_event.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Gnome_globe_current_event.svg/60px-Gnome_globe_current_event.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Gnome_globe_current_event.svg/80px-Gnome_globe_current_event.svg.png 2x" width="40"/></a> </div>
# </td>
# <td style="width: 84%"><b>Este artigo ou seção é sobre um evento <a href="/wiki/Desporto" title="Desporto">desportivo</a> <a href="/wiki/Portal:Eventos_atuais" title="Portal:Eventos atuais">atualmente</a> em curso.</b> <span style="font-size:88%"><span class="noprint">A informação apresentada pode mudar com frequência. Não adicione <a class="mw-redirect" href="/wiki/Wikip%C3%A9dia:CRISTAL" title="Wikipédia:CRISTAL">especulações</a>, nem texto sem <a class="mw-redirect" href="/wiki/Wikip%C3%A9dia:CITE" title="Wikipédia:CITE">referência</a> a <a href="/wiki/Wikip%C3%A9dia:Fontes_confi%C3%A1veis" title="Wikipédia:Fontes confiáveis">fontes confiáveis</a>. <i>(editado pela última vez em 25 de julho de 2019)</i></span></span>
# </td>
# <td style="width: 8%; text-align: center;"><a class="image" href="/wiki/Ficheiro:Sports_current_event.svg"><img alt="Sports current event.svg" data-file-height="460" data-file-width="527" decoding="async" height="38" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Sports_current_event.svg/43px-Sports_current_event.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Sports_current_event.svg/65px-Sports_current_event.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Sports_current_event.svg/86px-Sports_current_event.svg.png 2x" width="43"/></a>
# </td></tr></tbody></table>
# <table class="nowraplinks collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th class="navbox-title" colspan="2" scope="col"><div class="plainlinks hlist navbar mini"><ul><li class="nv-ver"><a href="/wiki/Predefini%C3%A7%C3%A3o:Futebol_na_Am%C3%A9rica_do_Sul_em_2019_(CONMEBOL)" title="Predefinição:Futebol na América do Sul em 2019 (CONMEBOL)"><abbr style=";;background:none transparent;border:none;-moz-box-shadow:none;-webkit-box-shadow:none;box-shadow:none; padding:0;" title="Ver esta predefinição">v</abbr></a></li><li class="nv-discutir"><a class="new" href="/w/index.php?title=Predefini%C3%A7%C3%A3o_Discuss%C3%A3o:Futebol_na_Am%C3%A9rica_do_Sul_em_2019_(CONMEBOL)&amp;action=edit&amp;redlink=1" title="Predefinição Discussão:Futebol na América do Sul em 2019 (CONMEBOL) (página não existe)"><abbr style=";;background:none transparent;border:none;-moz-box-shadow:none;-webkit-box-shadow:none;box-shadow:none; padding:0;" title="Discutir esta predefinição">d</abbr></a></li><li class="nv-editar"><a class="external text" href="//pt.wikipedia.org/w/index.php?title=Predefini%C3%A7%C3%A3o:Futebol_na_Am%C3%A9rica_do_Sul_em_2019_(CONMEBOL)&amp;action=edit"><abbr style=";;background:none transparent;border:none;-moz-box-shadow:none;-webkit-box-shadow:none;box-shadow:none; padding:0;" title="Editar esta predefinição">e</abbr></a></li></ul></div><div id="Futebol_na_América_do_Sul_em_2019_(CONMEBOL)" style="font-size:114%;margin:0 4em">Futebol na América do Sul em <a href="/wiki/2019_no_futebol" title="2019 no futebol">2019</a> (<a class="mw-redirect" href="/wiki/CONMEBOL" title="CONMEBOL">CONMEBOL</a>)</div></th></tr><tr><td class="navbox-abovebelow" colspan="2"><div id="«_2018_2020_»"><div style="float: left;"> « <span style="font-size:90%;"><a class="new" href="/w/index.php?title=Predefini%C3%A7%C3%A3o:Futebol_na_Am%C3%A9rica_do_Sul_em_2018_(CONMEBOL)&amp;action=edit&amp;redlink=1" title="Predefinição:Futebol na América do Sul em 2018 (CONMEBOL) (página não existe)">2018</a></span> </div> <div style="float: right;"><span style="font-size:90%;"><a class="new" href="/w/index.php?title=Predefini%C3%A7%C3%A3o:Futebol_na_Am%C3%A9rica_do_Sul_em_2020_(CONMEBOL)&amp;action=edit&amp;redlink=1" title="Predefinição:Futebol na América do Sul em 2020 (CONMEBOL) (página não existe)">2020</a></span> » </div></div></td></tr><tr><td class="navbox-list navbox-odd hlist" colspan="2" style="width:100%;padding:0px;background:transparent;color:inherit;"><div style="padding:0px;"><table class="navbox-columns-table" style="border-spacing: 0px; text-align:left;width:auto; margin-left:auto; margin-right:auto;"><tbody><tr style="vertical-align:top;"></tr></tbody></table></div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%">Campeonatos nacionais</th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
# <li><a href="/wiki/Recopa_Sul-Americana_de_2019" title="Recopa Sul-Americana de 2019">Recopa Sul-Americana</a></li>
# <li><a href="/wiki/Copa_Suruga_Bank_de_2019" title="Copa Suruga Bank de 2019">Final da J.League Cup/Copa Sudamericana</a></li>
# <li><a href="/wiki/Copa_Libertadores_da_Am%C3%A9rica_de_Futebol_Feminino_de_2019" title="Copa Libertadores da América de Futebol Feminino de 2019">Copa Libertadores Feminina</a></li></ul>
# </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%">Outras</th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
# <ul><li><a href="/wiki/Copa_da_Superliga_Argentina_de_Futebol_de_2019" title="Copa da Superliga Argentina de Futebol de 2019">Argentina</a></li></ul>
# </div></td></tr></tbody></table>

# %%
tabelas = pd.read_html(str(soup), header = 0)
len(tabelas)
# Out:
# 22

# %%
dados = tabelas[3]
dados.head(20) # esse 20 é o número de amostras (linhas) que eu quero
               # nesse caso 20 são todas as linhas
# Out:
#                   Equipe          Cidade Estado       Em 2018  \
# 0   Athletico Paranaense        Curitiba     PR            7º
# 1       Atlético Mineiro  Belo Horizonte     MG            6º
# 2                   Avaí   Florianópolis     SC  3º (Série B)
# 3                  Bahia        Salvador     BA           11º
# 4               Botafogo  Rio de Janeiro     RJ            9º
# 5                  Ceará       Fortaleza     CE           15°
# 6            Chapecoense         Chapecó     SC           14º
# 7            Corinthians       São Paulo     SP           13º
# 8               Cruzeiro  Belo Horizonte     MG            8º
# 9                    CSA          Maceió     AL  2º (Série B)
# 10              Flamengo  Rio de Janeiro     RJ            2º
# 11            Fluminense  Rio de Janeiro     RJ           12º
# 12             Fortaleza       Fortaleza     CE  1º (Série B)
# 13                 Goiás         Goiânia     GO  4º (Série B)
# 14                Grêmio    Porto Alegre     RS            4º
# 15         Internacional    Porto Alegre     RS            3°
# 16             Palmeiras       São Paulo     SP            1º
# 17                Santos          Santos     SP           10º
# 18             São Paulo       São Paulo     SP            5º
# 19         Vasco da Gama  Rio de Janeiro     RJ           16º
#
#       Estádio (mando) Capacidade[8]  \
# 0    Arena da Baixada     42 370[9]
# 1       Independência        23 018
# 2           Ressacada        17 826
# 3    Arena Fonte Nova        50 025
# 4       Nilton Santos        44 661
# 5      Arena Castelão        63 903
# 6         Arena Condá        20 089
# 7   Arena Corinthians        47 605
# 8            Mineirão        61 846
# 9            Rei Pelé    19 105[10]
# 10           Maracanã        78 838
# 11           Maracanã        78 838
# 12     Arena Castelão        63 903
# 13      Serra Dourada        42 000
# 14    Arena do Grêmio        55 662
# 15          Beira-Rio        50 128
# 16     Allianz Parque        43 713
# 17       Vila Belmiro        16 068
# 18            Morumbi        72 039
# 19       São Januário        21 680
#
#                                               Títulos
# 0                                            1 (2001)
# 1                                            1 (1971)
# 2                                      0 (não possui)
# 3                                      2 (1959, 1988)
# 4                              2 (1968[nota 1], 1995)
# 5                                      0 (não possui)
# 6                                      0 (não possui)
# 7        7 (1990, 1998, 1999, 2005, 2011, 2015, 2017)
# 8                          4 (1966, 2003, 2013, 2014)
# 9                                      0 (não possui)
# 10                   5 (1980, 1982, 1983, 1992, 2009)
# 11                         4 (1970, 1984, 2010, 2012)
# 12                                     0 (não possui)
# 13                                     0 (não possui)
# 14                                     2 (1981, 1996)
# 15                               3 (1975, 1976, 1979)
# 16  10 (1960, 1967[nota 1], 1967[nota 2], 1969, 19...
# 17  8 (1961, 1962, 1963, 1964, 1965, 1968[nota 2],...
# 18             6 (1977, 1986, 1991, 2006, 2007, 2008)
# 19                         4 (1974, 1989, 1997, 2000)

# %%
import requests
from bs4 import BeautifulSoup as bs

url = 'https://pt.wikipedia.org/wiki/Ubuntu'
resposta = requests.get(url)

soup = bs(resposta.text, 'html.parser')
tabela = soup.find_all('p')
print(tabela)

# %%
import requests
from bs4 import BeautifulSoup as bs

url = 'https://future.pinnacle.com/en'
resposta = requests.get(url)
with open('pin.html', 'wb') as arq:
    arq.write(resposta.content)

# %%
import requests
from bs4 import BeautifulSoup as bs

url = 'https://pt.wikipedia.org/wiki/Ubuntu'
resposta = requests.get(url)

page = bs(resposta.text, 'html.parser')
conteudo = page.find_all('a')
# print(conteudo, '\n') aqui é o conteúdo da linha anterior da tag "a"
print(conteudo[4], '\n') # esse conteúdo já vem de um "find (find_all no caso) e posso especificar com "[4]"
print(conteudo[4].find('abbr'), '\n') # eu posso ir de um "find" e usar "[]" e dá outro "find" e usar "[]" novamente
                                # e ir entrando mais na página e especificando mais ainda o que eu quero

print(conteudo[4].find('abbr').text, '\n') # nesses prints qnd cheguei onde queria, ainda mandei exibir só os textos
print(page.find_all('p')[3].text)
print(page.find('body').text)

# %%
import requests 
# do requests temos os métodos, get, post, put, delete. Para ver como funciona pesquisar
# se eu só vou usar o método get do requests, eu poderia apenas fazer:
# from requests import get
# e no lugar do códgigo abaixo: resposta = requests.get(url)
# eu faria apenas: resposta = get(url)

from bs4 import BeautifulSoup as bs

url = 'https://pt.wikipedia.org/wiki/Ubuntu'
resposta = requests.get(url)
print(f'A reposta do servidor é -> {resposta} \n\n')
print(f'O código da reposta do servidor é -> {resposta.status_code} \n\n')
print(f'O cabeçalho do servidor é -> {resposta.headers} \n\n')
print(f'Os cookies do servidor é -> {resposta.cookies} \n\n')
print(f'O texto do servidor que vamos usar com o BeautifulSoup é -> {resposta.text} \n\n')

# %%
page = bs(resposta.text, 'html.parser')

# a tag class que está dentro de table tbm pode ser especificada assim: 
#conteudo = page.find_all('table', class_='cquote')
conteudo = page.find('table', {'class': 'cquote'})
print('Aqui começa o uso do BeautifulSoup \n\n')
print(f'print direto no objeto page que recebe o BeautifulSoup {page} \n\n')
print('Usando o "find" e o "text" \n')
print(conteudo.text)

# se usássemos o "find_all" então para imprimirmos como texto, deveríamos dizer a posição
# do elemento mesmo que só tivesse 1. Neste caso usaríamos a posição "[0]" que é a primeira posição
# e como só temos 1 elemento, ele está na primeira posição. Se tivéssemos mais, faríamos "[1]" "[2]" e assim
# por diante. Veja o mesmo código usando o "find_all" e "text"

print('Agora usando o "find_all" e o "text" \n')
conteudo = page.find_all('table', {'class': 'cquote'})
print(conteudo[0].text)

# temos o get tbm para pegar atributos de uma tag assim como outros métodos do BeautifulSoup

# %%
# como essa página usa javascript, não funciona só com o requests
# nem importando o "time" e dando um sleep para carregar a página. Já testei 
# e pra testar novamente é só dá descomentar as duas linhas de códigos
# comentadas abaixo

# import time
from requests import get
from bs4 import BeautifulSoup as bs

url = 'https://future.pinnacle.com/en/'
resposta = get(url)
# time.sleep(20)
page = bs(resposta.text, 'html.parser')
print(page.find_all('span'))

# %%
# Aqui mesmo a página usando javascript conseguimos fazer web scraping 
# para isso usamos o selenium

# Aqui o firefox abre quando começar a executar o selenium
# serve como depuração tbm pra ver se está respondendo como deveria

import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver

url = 'https://future.pinnacle.com/en/'
driver = webdriver.Firefox()
driver.get(url)
time.sleep(15)
html = driver.execute_script("return document.documentElement.outerHTML")
page_bs = bs(html, 'html.parser')

erro_1 = 0
erro_2 = 0

try:
    tam_ao_vivo = len(page_bs.find('div', {'data-test-id':'LiveContainer'}).find_all('span', {'class':'_V4AXE'}))
    ao_vivo = page_bs.find('div', {'data-test-id':'LiveContainer'}).find_all('span', {'class':'_V4AXE'})
except:
    erro_1 = 1
    
try:
    tam_destaques = len(page_bs.find('div',{'data-test-id':'Highlights-Container'}).find_all('span', {'class':'_V4AXE'}))
    destaques = page_bs.find('div',{'data-test-id':'Highlights-Container'}).find_all('span', {'class':'_V4AXE'})
except:
    erro_2 = 1

if erro_1 == 0:
    print('Ao vivo\n')
    for i in range(tam_ao_vivo):
        print(ao_vivo[i].text)

if erro_2 == 0:
    print('\nDestaques\n')
    for i in range(tam_destaques): 
        print(destaques[i].text)

# %%
import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver

url = 'https://www.betfair.com/exchange/plus/football/inplay/'
driver = webdriver.Firefox()
driver.get(url)
time.sleep(15)
html = driver.execute_script("return document.documentElement.outerHTML")
page = bs(html, 'html.parser')
tamanho = len(page.find_all(class_='name'))
for i in range(tamanho):
    times = page.find_all(class_='name')
    print(times[i].text)
driver.quit() # aqui ao final fecha o navegador que estava aberto e visível

# %%
# para usar o selenium com firefox invísivel use o código abaixo

from selenium import webdriver

# local onde se encontra o instalador do geckdriver
geckodriver = '/home/andre/Downloads/geckodriver'

driver = webdriver.FirefoxOptions()
driver.add_argument('-headless')

driver = webdriver.Firefox(executable_path=geckodriver, options=driver)

driver.get('https://www.betfair.com/exchange/plus/football/inplay')
time.sleep(15)
driver.save_screenshot('/home/andre/Downloads/andre.png')

driver.quit()

# %%
# navegador invisível

from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time

geckodriver = '/home/andre/Downloads/geckodriver'
driver = webdriver.FirefoxOptions()
driver.add_argument('-headless')
driver = webdriver.Firefox(executable_path=geckodriver, options=driver)
driver.get('https://www.betfair.com/exchange/plus/football/inplay')
time.sleep(15)

html = driver.execute_script("return document.documentElement.outerHTML")
page = bs(html, 'html.parser')
tamanho = len(page.find_all(class_='name'))
for i in range(tamanho):
    times = page.find_all(class_='name')
    print(times[i].text)
driver.quit() # fecha o navegador que estava aberto porém invisível

# %%
# baixando a página HTLM da pinnacle
# posso fazer isso mostrando o navegador ou não
# neste caso optei por usar navegação invisível

import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver

gecko = '/home/andre/Downloads/geckodriver'
driver = webdriver.FirefoxOptions()
driver.add_argument('-headless')
driver = webdriver.Firefox(executable_path=gecko, options=driver)

url = 'https://future.pinnacle.com/en'
driver.get(url)
time.sleep(15)

html = driver.execute_script("return document.documentElement.outerHTML")
page = bs(html, 'html.parser')

with open('pinnacle.html', 'w') as arq:
    arq.write(html) # aqui tbm pode passar como parâmetro "page.text"

driver.quit()

# %%
# baixando a página HTLM da betfair
# posso fazer isso mostrando o navegador ou não
# neste caso optei por usar navegação invisível

import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver

gecko = '/home/andre/Downloads/geckodriver'
driver = webdriver.FirefoxOptions()
driver.add_argument('-headless')
driver = webdriver.Firefox(executable_path=gecko, options=driver)

url = 'https://www.betfair.com/exchange/plus/football/inplay/'
driver.get(url)
time.sleep(15)

html = driver.execute_script("return document.documentElement.outerHTML")
page = bs(html, 'html.parser')

with open('betfair.html', 'w') as arq:
    arq.write(html) # aqui tbm pode passar como parâmetro "page.text"

driver.quit()

# %%
# Aqui mesmo a página usando javascript conseguimos fazer web scraping 
# para isso usamos o selenium

# Aqui o firefox abre quando começar a executar o selenium
# serve como depuração tbm pra ver se está respondendo como deveria

import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver   

url = 'https://www.betfair.com/exchange/plus/football/inplay/'
driver = webdriver.Firefox()
driver.get(url)
time.sleep(2)

# a linha abaixo clica no menu dropdown e a próxima clica em umas das opções que 
# aparecem após o primeiro clique
driver.find_element_by_class_name('group-by-filter').click()
driver.find_element_by_css_selector('.expanded > div:nth-child(3) > bf-option:nth-child(2) > span:nth-child(1)').click()

time.sleep(15)
html = driver.execute_script("return document.documentElement.outerHTML")
page_selenium = bs(html, 'html.parser')

erro_1 = 0
erro_2 = 0

try:
    tam_ao_vivo = len(page_selenium.find_all('tbody')[1].find_all(class_='name'))
    ao_vivo = page_selenium.find_all('tbody')[1].find_all(class_='name')
except:
    erro_1 = 1
    
try:
    tam_a_seguir = len(page_selenium.find_all('tbody')[2].find_all(class_='name'))
    a_seguir = page_selenium.find_all('tbody')[2].find_all(class_='name')
except:
    erro_2 = 1

if erro_1 == 0:
    print('Ao vivo\n')
    for i in range(tam_ao_vivo):    
        print(ao_vivo[i].text)

if erro_2 == 0:
    print('\nA seguir\n')
    for i in range(tam_a_seguir):
        print(a_seguir[i].text)

# %%
# Aqui mesmo a página usando javascript conseguimos fazer web scraping 
# para isso usamos o selenium
# Aqui não abrimos o firefox

import time
from bs4 import BeautifulSoup as bs
from selenium import webdriver 

gecko = '/home/andre/Downloads/geckodriver'
driver = webdriver.FirefoxOptions()
driver.add_argument('-headless')
driver = webdriver.Firefox(executable_path=gecko, options=driver)

url = 'https://www.betfair.com/exchange/plus/football/inplay/'
driver.get(url)
time.sleep(2) # tempo para que o menu seja carregado e possa ser clicado

# a linha abaixo clica no menu dropdown e a próxima clica em umas das opções que 
# aparecem após o primeiro clique
driver.find_element_by_class_name('group-by-filter').click() 
driver.find_element_by_css_selector('.expanded > div:nth-child(3) > bf-option:nth-child(2) > span:nth-child(1)').click()

# tempo para processamento do javascript da página
time.sleep(15)
html = driver.execute_script("return document.documentElement.outerHTML")
page_selenium = bs(html, 'html.parser')

erro_1 = 0
erro_2 = 0

try:
    tam_ao_vivo = len(page_selenium.find_all('tbody')[1].find_all(class_='name'))
    ao_vivo = page_selenium.find_all('tbody')[1].find_all(class_='name')
except:
    erro_1 = 1
    
try:
    tam_a_seguir = len(page_selenium.find_all('tbody')[2].find_all(class_='name'))
    a_seguir = page_selenium.find_all('tbody')[2].find_all(class_='name')
except:
    erro_2 = 1

if erro_1 == 0:
    print('Ao vivo\n')
    for i in range(tam_ao_vivo):    
        print(ao_vivo[i].text)

if erro_2 == 0:
    print('\nA seguir\n')
    for i in range(tam_a_seguir):
        print(a_seguir[i].text)
        
driver.quit() # fecha o navegador que estava aberto e invisível
# Out:
# Ao vivo
#
# Club Necaxa (W)
# Guadalajara (W)
# GE Osasco SP
# Santo Andre
#
# A seguir
#
# América-MG
# Atlético-GO
# Nautico PE
# Confianca
# Velo Clube SP
# Rio Claro
# XV De Piracicaba
# Inter Limeira
# Botafogo SP
# CRB
# Guaraní
# São Bento
# New York City
# Kansas City
# Coquimbo Unido
# Univ de Concepcion
# Monarcas Morelia
# Atlas
# Racing Club
# Union Santa Fe
# Real Madrid
# Atletico Madrid
# Guayaquil City
# LDU
# Parana
# Sport Recife
# Los Angeles FC
# Atlanta Utd
# Veracruz
# Pachuca

# %%
# preenchendo um campo e apertando no botão correspondente para enviar os dados digitados

from selenium import webdriver

url = 'https://www.google.com.br/'
driver = webdriver.Firefox()
driver.get(url)

driver.find_element_by_css_selector('.gLFyf').send_keys('Digitado pelo Robô de André')
driver.find_element_by_css_selector('.FPdoLc > center:nth-child(1) > input:nth-child(1)').click()

# %%
# preenchendo um campo e apertando enter para enviar os dados digitados

from selenium import webdriver

url = 'https://www.google.com.br/'
driver = webdriver.Firefox()
driver.get(url)

elemento = driver.find_element_by_css_selector('.gLFyf')
elemento.send_keys('Digitado pelo Robô de André criado em Python!')
elemento.submit()

# %%
# robô que loga no facebook com clique no botão de login

from selenium import webdriver

driver = webdriver.Firefox()
driver.get('https://www.facebook.com')

driver.find_element_by_css_selector('#email').send_keys('anddre_oliveira@hotmail.com')
driver.find_element_by_css_selector('#pass').send_keys('andrews123')

# o botão para clicar poderia ter sido referenciado também pelo id ou outra coisa
# mas para referenciar por classe, só usamos o nome antes ou depois do espaço entre as palavras
# caso o nome da classe tenha mais de um nome
driver.find_element_by_class_name('uiButton').click()

# %%
# robô que loga no facebook apertando enter para na hora de logar

from selenium import webdriver

driver = webdriver.Firefox()
driver.get('https://www.facebook.com')

elemento = driver.find_element_by_css_selector('#email')
elemento.send_keys('anddre_oliveira@hotmail.com')
elemento = driver.find_element_by_css_selector('#pass')
elemento.send_keys('andrews123')
elemento.submit()
